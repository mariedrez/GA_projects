# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Ames Housing Data and Kaggle Challenge

# %% [markdown]
# ## Data Cleaning for test data

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

from IPython.display import HTML
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %matplotlib inline

# Set style for plots
plt.style.use('fivethirtyeight')

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (11, 11)
plt.rcParams['font.size'] = 14

# %%
# Change display settings for pandas
pd.set_option("display.max_rows", 90)
pd.set_option("display.max_columns", 90)

# %% [markdown]
# ### Import Data

# %%
# read in the data using pandas
test = pd.read_csv('./data/test.csv')

# remove space in column titles
test.columns = test.columns.str.replace(' ', '')

# convert column titles to all lowercase
test.columns = [x.lower() for x in test.columns]

# %% [markdown]
# **Initial examination of data**

# %%
# show first 5 rows of data
test.head()
# Out:
#      id        pid  mssubclass mszoning  lotfrontage  lotarea street alley  \
# 0  2658  902301120         190       RM         69.0     9142   Pave  Grvl
# 1  2718  905108090          90       RL          NaN     9662   Pave   NaN
# 2  2414  528218130          60       RL         58.0    17104   Pave   NaN
# 3  1989  902207150          30       RM         60.0     8520   Pave   NaN
# 4   625  535105100          20       RL          NaN     9500   Pave   NaN
#
#   lotshape landcontour utilities lotconfig landslope neighborhood condition1  \
# 0      Reg         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1      IR1         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 2      IR1         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3      Reg         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 4      IR1         Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#   condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  \
# 0       Norm   2fmCon     2Story            6            8       1910
# 1       Norm   Duplex     1Story            5            4       1977
# 2       Norm     1Fam     2Story            7            5       2006
# 3       Norm     1Fam     1Story            5            6       1923
# 4       Norm     1Fam     1Story            6            5       1963
#
#    yearremod/add roofstyle roofmatl exterior1st exterior2nd masvnrtype  \
# 0           1950     Gable  CompShg     AsbShng     AsbShng       None
# 1           1977     Gable  CompShg     Plywood     Plywood       None
# 2           2006     Gable  CompShg     VinylSd     VinylSd       None
# 3           2006     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 4           1963     Gable  CompShg     Plywood     Plywood    BrkFace
#
#    masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure  \
# 0         0.0        TA        Fa      Stone       Fa       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           No
# 2         0.0        Gd        TA      PConc       Gd       Gd           Av
# 3         0.0        Gd        TA     CBlock       TA       TA           No
# 4       247.0        TA        TA     CBlock       Gd       TA           No
#
#   bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf  \
# 0          Unf           0          Unf           0       1020         1020
# 1          Unf           0          Unf           0       1967         1967
# 2          GLQ         554          Unf           0        100          654
# 3          Unf           0          Unf           0        968          968
# 4          BLQ         609          Unf           0        785         1394
#
#   heating heatingqc centralair electrical  1stflrsf  2ndflrsf  lowqualfinsf  \
# 0    GasA        Gd          N      FuseP       908      1020             0
# 1    GasA        TA          Y      SBrkr      1967         0             0
# 2    GasA        Ex          Y      SBrkr       664       832             0
# 3    GasA        TA          Y      SBrkr       968         0             0
# 4    GasA        Gd          Y      SBrkr      1394         0             0
#
#    grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  \
# 0       1928             0             0         2         0             4
# 1       1967             0             0         2         0             6
# 2       1496             1             0         2         1             3
# 3        968             0             0         1         0             2
# 4       1394             1             0         1         1             3
#
#    kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces fireplacequ  \
# 0             2          Fa             9        Typ           0         NaN
# 1             2          TA            10        Typ           0         NaN
# 2             1          Gd             7        Typ           1          Gd
# 3             1          TA             5        Typ           0         NaN
# 4             1          TA             6        Typ           2          Gd
#
#   garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal  \
# 0     Detchd       1910.0          Unf           1         440         Po
# 1     Attchd       1977.0          Fin           2         580         TA
# 2     Attchd       2006.0          RFn           2         426         TA
# 3     Detchd       1935.0          Unf           2         480         Fa
# 4     Attchd       1963.0          RFn           2         514         TA
#
#   garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  \
# 0         Po          Y           0           60            112          0
# 1         TA          Y         170            0              0          0
# 2         TA          Y         100           24              0          0
# 3         TA          N           0            0            184          0
# 4         TA          Y           0           76              0          0
#
#    screenporch  poolarea poolqc fence miscfeature  miscval  mosold  yrsold  \
# 0            0         0    NaN   NaN         NaN        0       4    2006
# 1            0         0    NaN   NaN         NaN        0       8    2006
# 2            0         0    NaN   NaN         NaN        0       9    2006
# 3            0         0    NaN   NaN         NaN        0       7    2007
# 4          185         0    NaN   NaN         NaN        0       7    2009
#
#   saletype
# 0      WD
# 1      WD
# 2      New
# 3      WD
# 4      WD

# %%
# describe dataset
test.describe().T
# Out:
#                count          mean           std          min           25%  \
# id             878.0  1.444749e+03  8.508383e+02          2.0  6.922500e+02
# pid            878.0  7.162867e+08  1.889103e+08  526302110.0  5.284841e+08
# mssubclass     878.0  5.826879e+01  4.223541e+01         20.0  2.000000e+01
# lotfrontage    718.0  6.954596e+01  2.353394e+01         21.0  5.900000e+01
# lotarea        878.0  1.030703e+04  1.000267e+04       1477.0  7.297250e+03
# overallqual    878.0  6.050114e+00  1.369065e+00          2.0  5.000000e+00
# overallcond    878.0  5.566059e+00  1.128903e+00          1.0  5.000000e+00
# yearbuilt      878.0  1.970492e+03  3.039589e+01       1880.0  1.954000e+03
# yearremod/add  878.0  1.984418e+03  2.045072e+01       1950.0  1.967000e+03
# masvnrarea     877.0  1.062360e+02  1.871589e+02          0.0  0.000000e+00
# bsmtfinsf1     878.0  4.413280e+02  4.384573e+02          0.0  0.000000e+00
# bsmtfinsf2     878.0  5.389636e+01  1.786324e+02          0.0  0.000000e+00
# bsmtunfsf      878.0  5.391333e+02  4.261722e+02          0.0  2.160000e+02
# totalbsmtsf    878.0  1.034358e+03  4.134463e+02          0.0  7.890000e+02
# 1stflrsf       878.0  1.145787e+03  3.752641e+02        407.0  8.640000e+02
# 2ndflrsf       878.0  3.483986e+02  4.329856e+02          0.0  0.000000e+00
# lowqualfinsf   878.0  2.728929e+00  3.257255e+01          0.0  0.000000e+00
# grlivarea      878.0  1.496915e+03  5.064690e+02        407.0  1.114000e+03
# bsmtfullbath   878.0  4.396355e-01  5.299477e-01          0.0  0.000000e+00
# bsmthalfbath   878.0  5.580866e-02  2.296827e-01          0.0  0.000000e+00
# fullbath       878.0  1.539863e+00  5.590601e-01          0.0  1.000000e+00
# halfbath       878.0  3.986333e-01  5.059265e-01          0.0  0.000000e+00
# bedroomabvgr   878.0  2.879271e+00  8.307123e-01          0.0  2.000000e+00
# kitchenabvgr   878.0  1.047836e+00  2.239657e-01          0.0  1.000000e+00
# totrmsabvgrd   878.0  6.454442e+00  1.596632e+00          3.0  5.000000e+00
# fireplaces     878.0  6.184510e-01  6.695708e-01          0.0  0.000000e+00
# garageyrblt    833.0  1.976760e+03  2.568976e+01       1900.0  1.960000e+03
# garagecars     878.0  1.742597e+00  7.503909e-01          0.0  1.000000e+00
# garagearea     878.0  4.703622e+02  2.127341e+02          0.0  3.225000e+02
# wooddecksf     878.0  9.343052e+01  1.211817e+02          0.0  0.000000e+00
# openporchsf    878.0  4.707062e+01  6.818094e+01          0.0  0.000000e+00
# enclosedporch  878.0  2.406492e+01  7.324946e+01          0.0  0.000000e+00
# 3ssnporch      878.0  2.597950e+00  2.496248e+01          0.0  0.000000e+00
# screenporch    878.0  1.483030e+01  5.300379e+01          0.0  0.000000e+00
# poolarea       878.0  1.884966e+00  2.991667e+01          0.0  0.000000e+00
# miscval        878.0  4.849886e+01  5.501693e+02          0.0  0.000000e+00
# mosold         878.0  6.202733e+00  2.642498e+00          1.0  5.000000e+00
# yrsold         878.0  2.007826e+03  1.327861e+00       2006.0  2.007000e+03
#
#                        50%           75%           max
# id                  1433.0  2.197500e+03  2.928000e+03
# pid            535454155.0  9.071904e+08  1.007100e+09
# mssubclass            50.0  7.000000e+01  1.900000e+02
# lotfrontage           68.0  8.000000e+01  1.820000e+02
# lotarea             9446.0  1.158900e+04  2.152450e+05
# overallqual            6.0  7.000000e+00  1.000000e+01
# overallcond            5.0  6.000000e+00  9.000000e+00
# yearbuilt           1972.0  1.999750e+03  2.010000e+03
# yearremod/add       1992.0  2.003000e+03  2.010000e+03
# masvnrarea             0.0  1.720000e+02  1.378000e+03
# bsmtfinsf1           373.0  7.347500e+02  2.288000e+03
# bsmtfinsf2             0.0  0.000000e+00  1.526000e+03
# bsmtunfsf            452.0  7.800000e+02  2.046000e+03
# totalbsmtsf          975.0  1.247000e+03  2.630000e+03
# 1stflrsf            1063.0  1.358000e+03  2.674000e+03
# 2ndflrsf               0.0  7.200000e+02  2.065000e+03
# lowqualfinsf           0.0  0.000000e+00  4.810000e+02
# grlivarea           1436.0  1.779000e+03  4.476000e+03
# bsmtfullbath           0.0  1.000000e+00  2.000000e+00
# bsmthalfbath           0.0  0.000000e+00  1.000000e+00
# fullbath               2.0  2.000000e+00  4.000000e+00
# halfbath               0.0  1.000000e+00  2.000000e+00
# bedroomabvgr           3.0  3.000000e+00  6.000000e+00
# kitchenabvgr           1.0  1.000000e+00  3.000000e+00
# totrmsabvgrd           6.0  7.000000e+00  1.200000e+01
# fireplaces             1.0  1.000000e+00  3.000000e+00
# garageyrblt         1978.0  2.001000e+03  2.010000e+03
# garagecars             2.0  2.000000e+00  4.000000e+00
# garagearea           473.0  5.760000e+02  1.488000e+03
# wooddecksf             0.0  1.707500e+02  6.900000e+02
# openporchsf           27.0  6.975000e+01  7.420000e+02
# enclosedporch          0.0  0.000000e+00  1.012000e+03
# 3ssnporch              0.0  0.000000e+00  3.600000e+02
# screenporch            0.0  0.000000e+00  5.760000e+02
# poolarea               0.0  0.000000e+00  5.550000e+02
# miscval                0.0  0.000000e+00  1.550000e+04
# mosold                 6.0  8.000000e+00  1.200000e+01
# yrsold              2008.0  2.009000e+03  2.010000e+03

# %%
# summarise dataset
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             878 non-null    int64
#  1   pid            878 non-null    int64
#  2   mssubclass     878 non-null    int64
#  3   mszoning       878 non-null    object
#  4   lotfrontage    718 non-null    float64
#  5   lotarea        878 non-null    int64
#  6   street         878 non-null    object
#  7   alley          58 non-null     object
#  8   lotshape       878 non-null    object
#  9   landcontour    878 non-null    object
#  10  utilities      878 non-null    object
#  11  lotconfig      878 non-null    object
#  12  landslope      878 non-null    object
#  13  neighborhood   878 non-null    object
#  14  condition1     878 non-null    object
#  15  condition2     878 non-null    object
#  16  bldgtype       878 non-null    object
#  17  housestyle     878 non-null    object
#  18  overallqual    878 non-null    int64
#  19  overallcond    878 non-null    int64
#  20  yearbuilt      878 non-null    int64
#  21  yearremod/add  878 non-null    int64
#  22  roofstyle      878 non-null    object
#  23  roofmatl       878 non-null    object
#  24  exterior1st    878 non-null    object
#  25  exterior2nd    878 non-null    object
#  26  masvnrtype     877 non-null    object
#  27  masvnrarea     877 non-null    float64
#  28  exterqual      878 non-null    object
#  29  extercond      878 non-null    object
#  30  foundation     878 non-null    object
#  31  bsmtqual       853 non-null    object
#  32  bsmtcond       853 non-null    object
#  33  bsmtexposure   853 non-null    object
#  34  bsmtfintype1   853 non-null    object
#  35  bsmtfinsf1     878 non-null    int64
#  36  bsmtfintype2   853 non-null    object
#  37  bsmtfinsf2     878 non-null    int64
#  38  bsmtunfsf      878 non-null    int64
#  39  totalbsmtsf    878 non-null    int64
#  40  heating        878 non-null    object
#  41  heatingqc      878 non-null    object
#  42  centralair     878 non-null    object
#  43  electrical     877 non-null    object
#  44  1stflrsf       878 non-null    int64
#  45  2ndflrsf       878 non-null    int64
#  46  lowqualfinsf   878 non-null    int64
#  47  grlivarea      878 non-null    int64
#  48  bsmtfullbath   878 non-null    int64
#  49  bsmthalfbath   878 non-null    int64
#  50  fullbath       878 non-null    int64
#  51  halfbath       878 non-null    int64
#  52  bedroomabvgr   878 non-null    int64
#  53  kitchenabvgr   878 non-null    int64
#  54  kitchenqual    878 non-null    object
#  55  totrmsabvgrd   878 non-null    int64
#  56  functional     878 non-null    object
#  57  fireplaces     878 non-null    int64
#  58  fireplacequ    456 non-null    object
#  59  garagetype     834 non-null    object
#  60  garageyrblt    833 non-null    float64
#  61  garagefinish   833 non-null    object
#  62  garagecars     878 non-null    int64
#  63  garagearea     878 non-null    int64
#  64  garagequal     833 non-null    object
#  65  garagecond     833 non-null    object
#  66  paveddrive     878 non-null    object
#  67  wooddecksf     878 non-null    int64
#  68  openporchsf    878 non-null    int64
#  69  enclosedporch  878 non-null    int64
#  70  3ssnporch      878 non-null    int64
#  71  screenporch    878 non-null    int64
#  72  poolarea       878 non-null    int64
#  73  poolqc         4 non-null      object
#  74  fence          172 non-null    object
#  75  miscfeature    41 non-null     object
#  76  miscval        878 non-null    int64
#  77  mosold         878 non-null    int64
#  78  yrsold         878 non-null    int64
#  79  saletype       878 non-null    object
# dtypes: float64(3), int64(35), object(42)
# memory usage: 548.9+ KB

# %% [markdown]
# **Remove outliers mentioned in dataset notes**

# %%
# view dataset shape to track the changes
test.shape

# number of rows has dropped from 2051 to 2049
# Out:
# (878, 80)

# %% [markdown]
# **Remove features wholly irrelevant to SalePrice**

# %%
test.drop(columns=['id', 'pid', 'saletype'], inplace=True)

# %% [markdown]
# **Reformat mssubclass column**

# %%
test['mssubclass']= test['mssubclass'].apply(lambda x: 'sub' + str(x).rjust(3, '0'))
test.head(3)
# Out:
#   mssubclass mszoning  lotfrontage  lotarea street alley lotshape landcontour  \
# 0     sub190       RM         69.0     9142   Pave  Grvl      Reg         Lvl
# 1     sub090       RL          NaN     9662   Pave   NaN      IR1         Lvl
# 2     sub060       RL         58.0    17104   Pave   NaN      IR1         Lvl
#
#   utilities lotconfig landslope neighborhood condition1 condition2 bldgtype  \
# 0    AllPub    Inside       Gtl      OldTown       Norm       Norm   2fmCon
# 1    AllPub    Inside       Gtl       Sawyer       Norm       Norm   Duplex
# 2    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam
#
#   housestyle  overallqual  overallcond  yearbuilt  yearremod/add roofstyle  \
# 0     2Story            6            8       1910           1950     Gable
# 1     1Story            5            4       1977           1977     Gable
# 2     2Story            7            5       2006           2006     Gable
#
#   roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond  \
# 0  CompShg     AsbShng     AsbShng       None         0.0        TA        Fa
# 1  CompShg     Plywood     Plywood       None         0.0        TA        TA
# 2  CompShg     VinylSd     VinylSd       None         0.0        Gd        TA
#
#   foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1  \
# 0      Stone       Fa       TA           No          Unf           0
# 1     CBlock       Gd       TA           No          Unf           0
# 2      PConc       Gd       Gd           Av          GLQ         554
#
#   bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc  \
# 0          Unf           0       1020         1020    GasA        Gd
# 1          Unf           0       1967         1967    GasA        TA
# 2          Unf           0        100          654    GasA        Ex
#
#   centralair electrical  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  \
# 0          N      FuseP       908      1020             0       1928
# 1          Y      SBrkr      1967         0             0       1967
# 2          Y      SBrkr       664       832             0       1496
#
#    bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr  \
# 0             0             0         2         0             4             2
# 1             0             0         2         0             6             2
# 2             1             0         2         1             3             1
#
#   kitchenqual  totrmsabvgrd functional  fireplaces fireplacequ garagetype  \
# 0          Fa             9        Typ           0         NaN     Detchd
# 1          TA            10        Typ           0         NaN     Attchd
# 2          Gd             7        Typ           1          Gd     Attchd
#
#    garageyrblt garagefinish  garagecars  garagearea garagequal garagecond  \
# 0       1910.0          Unf           1         440         Po         Po
# 1       1977.0          Fin           2         580         TA         TA
# 2       2006.0          RFn           2         426         TA         TA
#
#   paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  \
# 0          Y           0           60            112          0            0
# 1          Y         170            0              0          0            0
# 2          Y         100           24              0          0            0
#
#    poolarea poolqc fence miscfeature  miscval  mosold  yrsold
# 0         0    NaN   NaN         NaN        0       4    2006
# 1         0    NaN   NaN         NaN        0       8    2006
# 2         0    NaN   NaN         NaN        0       9    2006

# %% [markdown]
# **Cleaning up the mszoning column**

# %%
# show unique values listed under mszoning column
test.mszoning.unique()
# Out:
# array(['RM', 'RL', 'FV', 'RH', 'C (all)', 'I (all)'], dtype=object)

# %% [markdown]
# **Null values** <br>
# Passing the info() method on the dataset revealed that there are several columns with less than 2051 observations, which means that there is a number of missing data.

# %%
# check for null values in dataset
null_values = pd.DataFrame(test.isnull().sum(), columns=['count_null_values'])

# add another column to calculate % of null values in each column of test dataset
null_values['pctg_null_values'] = (null_values['count_null_values'] / 2049) * 100

# sort columns according to null values in descending order
null_values.sort_values(by='count_null_values', ascending = False)
# Out:
#                count_null_values  pctg_null_values
# poolqc                       874         42.654954
# miscfeature                  837         40.849195
# alley                        820         40.019522
# fence                        706         34.455832
# fireplacequ                  422         20.595412
# lotfrontage                  160          7.808687
# garageyrblt                   45          2.196193
# garagecond                    45          2.196193
# garagefinish                  45          2.196193
# garagequal                    45          2.196193
# garagetype                    44          2.147389
# bsmtcond                      25          1.220107
# bsmtexposure                  25          1.220107
# bsmtfintype1                  25          1.220107
# bsmtqual                      25          1.220107
# bsmtfintype2                  25          1.220107
# electrical                     1          0.048804
# masvnrtype                     1          0.048804
# masvnrarea                     1          0.048804
# kitchenqual                    0          0.000000
# totrmsabvgrd                   0          0.000000
# bedroomabvgr                   0          0.000000
# halfbath                       0          0.000000
# fullbath                       0          0.000000
# bsmthalfbath                   0          0.000000
# bsmtfullbath                   0          0.000000
# kitchenabvgr                   0          0.000000
# mssubclass                     0          0.000000
# functional                     0          0.000000
# fireplaces                     0          0.000000
# lowqualfinsf                   0          0.000000
# garagecars                     0          0.000000
# garagearea                     0          0.000000
# paveddrive                     0          0.000000
# wooddecksf                     0          0.000000
# openporchsf                    0          0.000000
# enclosedporch                  0          0.000000
# 3ssnporch                      0          0.000000
# screenporch                    0          0.000000
# poolarea                       0          0.000000
# miscval                        0          0.000000
# mosold                         0          0.000000
# grlivarea                      0          0.000000
# heating                        0          0.000000
# 2ndflrsf                       0          0.000000
# yearbuilt                      0          0.000000
# lotarea                        0          0.000000
# street                         0          0.000000
# lotshape                       0          0.000000
# landcontour                    0          0.000000
# utilities                      0          0.000000
# lotconfig                      0          0.000000
# landslope                      0          0.000000
# neighborhood                   0          0.000000
# condition1                     0          0.000000
# condition2                     0          0.000000
# bldgtype                       0          0.000000
# housestyle                     0          0.000000
# overallqual                    0          0.000000
# overallcond                    0          0.000000
# yearremod/add                  0          0.000000
# 1stflrsf                       0          0.000000
# roofstyle                      0          0.000000
# roofmatl                       0          0.000000
# exterior1st                    0          0.000000
# exterior2nd                    0          0.000000
# exterqual                      0          0.000000
# extercond                      0          0.000000
# foundation                     0          0.000000
# bsmtfinsf1                     0          0.000000
# bsmtfinsf2                     0          0.000000
# bsmtunfsf                      0          0.000000
# totalbsmtsf                    0          0.000000
# mszoning                       0          0.000000
# heatingqc                      0          0.000000
# centralair                     0          0.000000
# yrsold                         0          0.000000

# %% [markdown]
# **Remove columns with excessive null values** <br>
# There are 26 columns with some amount of missing data, of which 'poolqc' is the most sparsely populated with over 98.4% of missing observations. The columns 'poolqc' will be dropped along with 'miscfeature' and 'alley' as these contain data for less than 10% of the total observations.

# %%
# drop columns with over 90% null values
test.drop(labels=['poolqc','miscfeature','alley'],axis=1, inplace=True)

# view dataset shape
# number of rows dropped from 81 to 78
test.shape
# Out:
# (878, 74)

# %% [markdown]
# **Fireplacequ null values** <br>
# The next column with highest number of null values observed is 'fireplacequ'. Exploratory analyses on columns with fireplace-related data show that observations with zero fireplaces also have null values in 'fireplacequ'. The data is missing not at random. Null values in 'fireplacequ' will be replaced with a '0' rating as we convert the ordinal data in the column to numerical type.

# %%
# show fireplace-related data
test_fireplace = test[['fireplacequ','fireplaces']]
grpby_fireplace = test_fireplace.groupby(['fireplacequ'])
grpby_fireplace.sum()
# Out:
#              fireplaces
# fireplacequ
# Ex                   17
# Fa                   17
# Gd                  264
# Po                   15
# TA                  230

# %%
# null values in fireplacequ correlate with zero fireplaces observed
display(test[test.fireplaces & test.fireplacequ.isnull()])
# Out:
# Empty DataFrame
# Columns: [mssubclass, mszoning, lotfrontage, lotarea, street, lotshape, landcontour, utilities, lotconfig, landslope, neighborhood, condition1, condition2, bldgtype, housestyle, overallqual, overallcond, yearbuilt, yearremod/add, roofstyle, roofmatl, exterior1st, exterior2nd, masvnrtype, masvnrarea, exterqual, extercond, foundation, bsmtqual, bsmtcond, bsmtexposure, bsmtfintype1, bsmtfinsf1, bsmtfintype2, bsmtfinsf2, bsmtunfsf, totalbsmtsf, heating, heatingqc, centralair, electrical, 1stflrsf, 2ndflrsf, lowqualfinsf, grlivarea, bsmtfullbath, bsmthalfbath, fullbath, halfbath, bedroomabvgr, kitchenabvgr, kitchenqual, totrmsabvgrd, functional, fireplaces, fireplacequ, garagetype, garageyrblt, garagefinish, garagecars, garagearea, garagequal, garagecond, paveddrive, wooddecksf, openporchsf, enclosedporch, 3ssnporch, screenporch, poolarea, fence, miscval, mosold, yrsold]
# Index: []

# %%
# Let's impute missing values in the fireplacequ column with fillna for the time being
test.fireplacequ.fillna(value='NA', inplace=True)

# check for null values in fireplacequ column
test.fireplacequ.isnull().sum()
# Out:
# 0

# %% [markdown]
# **Lot-related null values**

# %%
# show lot-related data
test_lots = test[['lotfrontage', 'lotarea', 'lotshape', 'lotconfig']]
display(test_lots.head())
# Out:
#    lotfrontage  lotarea lotshape lotconfig
# 0         69.0     9142      Reg    Inside
# 1          NaN     9662      IR1    Inside
# 2         58.0    17104      IR1    Inside
# 3         60.0     8520      Reg    Inside
# 4          NaN     9500      IR1    Inside

# %%
# do groupby based on 'lotshape'
# take mean as lotfrontage and lotarea are continuous datatype
grpby_lotshape = test_lots.groupby(['lotshape'])
grpby_lotshape.mean()
# Out:
#           lotfrontage       lotarea
# lotshape
# IR1         75.108696  11622.220280
# IR2         91.500000  16078.238095
# IR3        120.000000  46158.142857
# Reg         66.568665   8980.265957

# %%
# do groupby based on 'lotconfig'
# use .count to see how lotfrontage observations compare with other lot-related data
grpby_lotconfig = test_lots.groupby(['lotconfig'])
grpby_lotconfig.count()
# Out:
#            lotfrontage  lotarea  lotshape
# lotconfig
# Corner             126      163       163
# CulDSac             22       49        49
# FR2                 16       25        25
# FR3                  2        5         5
# Inside             552      636       636

# %% [markdown]
# Lot frontage refers to the width of a lot, measured at the front part of the lot. In other words, it measures the boundary between the property and the road onto which the property faces [(Source)](https://en.wikipedia.org/wiki/Frontage). As such, lot frontage is highly related to lot shape and lot configuration.

# %%
# Let's impute missing values in the lotfrontage column with the mean based on the lotshape
test_lotfront_null = test_lots.loc[(test['lotfrontage'].isnull())]

# %%
# mean lotfrontage for IR1 == 74.402570
test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 74.402570 if (x[2] == 'IR1') 
                                                           else x[0], axis=1)

# mean lotfrontage for IR2 == 59.416667
test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 59.416667 if (x[2] == 'IR2') 
                                                               else x[0], axis=1)

# mean lotfrontage for IR3 == 76.200000
test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 76.200000 if (x[2] == 'IR3') 
                                                               else x[0], axis=1)

# mean lotfrontage for reg == 66.952061 
test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 66.952061 if (x[2] == 'Reg') 
                                                               else x[0], axis=1)
# Out:
# /var/folders/n2/ln256wq518d5zk05dzh0wrsw0000gn/T/ipykernel_28372/1651271080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 74.402570 if (x[2] == 'IR1')
# /var/folders/n2/ln256wq518d5zk05dzh0wrsw0000gn/T/ipykernel_28372/1651271080.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 59.416667 if (x[2] == 'IR2')
# /var/folders/n2/ln256wq518d5zk05dzh0wrsw0000gn/T/ipykernel_28372/1651271080.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 76.200000 if (x[2] == 'IR3')
# /var/folders/n2/ln256wq518d5zk05dzh0wrsw0000gn/T/ipykernel_28372/1651271080.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_lotfront_null['lotfrontage'] = test_lotfront_null.apply(lambda x: 66.952061 if (x[2] == 'Reg')

# %%
# assign imputed mean values into the rows with nulls in lotfrontage column
lotfront_imputed = test_lotfront_null.lotfrontage
test.loc[test.lotfrontage.isnull(), 'lotfrontage'] = lotfront_imputed

# %%
# check for changes
test.lotfrontage.sort_values()
# Out:
# 723     21.0
# 45      21.0
# 371     21.0
# 482     21.0
# 536     21.0
#        ...
# 668    160.0
# 170    160.0
# 264    168.0
# 234    174.0
# 870    182.0
# Name: lotfrontage, Length: 878, dtype: float64

# %% [markdown]
# **Garage-related null values**
#
# There are 114 null values for four garage-related columns:'garagefinish','garagequal','garageyrblt','garagecond'.
# As the indices for these null values overlap, we can conclude that there are 114 properties without a garage.

# %%
print(test['garagefinish'])
print(test['garagequal'])
print(test['garageyrblt'])
print(test['garagecond'])
# Out:
# 0      Unf
# 1      Fin
# 2      RFn
# 3      Unf
# 4      RFn
#       ...
# 873    Unf
# 874    RFn
# 875    Unf
# 876    Unf
# 877    Unf
# Name: garagefinish, Length: 878, dtype: object
# 0      Po
# 1      TA
# 2      TA
# 3      Fa
# 4      TA
#        ..
# 873    TA
# 874    TA
# 875    TA
# 876    TA
# 877    TA
# Name: garagequal, Length: 878, dtype: object
# 0      1910.0
# 1      1977.0
# 2      2006.0
# 3      1935.0
# 4      1963.0
#         ...
# 873    1974.0
# 874    1966.0
# 875    1968.0
# 876    1974.0
# 877    1955.0
# Name: garageyrblt, Length: 878, dtype: float64
# 0      Po
# 1      TA
# 2      TA
# 3      TA
# 4      TA
#        ..
# 873    TA
# 874    TA
# 875    TA
# 876    TA
# 877    TA
# Name: garagecond, Length: 878, dtype: object

# %%
print(test[test['garagefinish'].isnull()])
print(test[test['garagequal'].isnull()])
print(test[test['garageyrblt'].isnull()])
print(test[test['garagecond'].isnull()])
# Out:
#     mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour  \
# 29      sub050       RL    51.000000     3500   Pave      Reg         Lvl
# 45      sub160       RM    21.000000     1533   Pave      Reg         Lvl
# 66      sub020       RL    74.402570     8125   Pave      IR1         Lvl
# 68      sub030       RH    70.000000     4270   Pave      Reg         Bnk
# 105     sub030       RM    40.000000     3880   Pave      Reg         Lvl
# 109     sub090       RL    72.000000    10773   Pave      Reg         Lvl
# 113     sub020       RL    90.000000    17217   Pave      Reg         Lvl
# 144     sub050       RL    57.000000     8050   Pave      Reg         Lvl
# 152     sub050       RM    60.000000     5586   Pave      IR1         Bnk
# 156     sub160       RM    21.000000     1900   Pave      Reg         Lvl
# 180     sub050       RL    51.000000     9839   Pave      Reg         Lvl
# 218     sub085       RM    86.000000     5160   Pave      Reg         Lvl
# 230     sub030       RL    85.000000    19550   Pave      Reg         Lvl
# 231     sub180       RM    21.000000     1491   Pave      Reg         Lvl
# 256     sub050       RM    55.000000     8800   Pave      Reg         Lvl
# 282     sub020       RL    63.000000    10712   Pave      Reg         Lvl
# 305     sub020       RL    66.952061     9000   Pave      Reg         Lvl
# 314     sub090       RH    60.000000     7200   Pave      Reg         Lvl
# 320     sub050       RM    52.000000     6240   Pave      Reg         Lvl
# 337     sub050       RL    60.000000    14190   Pave      Reg         Lvl
# 341     sub050       RM    56.000000    10134   Pave      Reg         Lvl
# 350     sub190       RM    41.000000     5852   Pave      IR3         Bnk
# 359     sub050       RM    85.000000     8500   Pave      Reg         Lvl
# 395     sub030  C (all)    66.952061     3300   Pave      Reg         Lvl
# 482     sub180       RM    21.000000     1533   Pave      Reg         Lvl
# 496     sub190       RL    60.000000     9900   Pave      Reg         Lvl
# 527     sub090       RL    75.000000     9825   Pave      Reg         Lvl
# 529     sub030       RL    90.000000     5400   Pave      Reg         Lvl
# 536     sub160       RM    21.000000     1526   Pave      Reg         Lvl
# 555     sub045       RM    55.000000     4388   Pave      IR1         Bnk
# 566     sub020       RL    63.000000    13072   Pave      Reg         Lvl
# 591     sub085       RL    50.000000     6723   Pave      Reg         Lvl
# 596     sub070       RM    60.000000     6000   Pave      Reg         Lvl
# 610     sub050       RL    60.000000    12180   Pave      Reg         Lvl
# 615     sub030       RM    51.000000     6120   Pave      Reg         Lvl
# 618     sub090       RL    74.000000     6882   Pave      Reg         Lvl
# 629     sub020       RL    63.000000    13072   Pave      Reg         Lvl
# 674     sub085       RL    62.000000    10441   Pave      Reg         Lvl
# 698     sub090       RL    50.000000     9350   Pave      Reg         Lvl
# 711     sub190       RM    33.000000     4456   Pave      Reg         Lvl
# 764     sub060       RM    57.000000     8094   Pave      Reg         Lvl
# 779     sub090       RL    60.000000    10890   Pave      Reg         Lvl
# 803     sub070  C (all)    74.402570     6449   Pave      IR1         Lvl
# 813     sub090       RL    98.000000    13260   Pave      IR1         Lvl
# 859     sub020       RL    74.402570     8780   Pave      IR1         Lvl
#
#     utilities lotconfig landslope neighborhood condition1 condition2 bldgtype  \
# 29     AllPub    Inside       Gtl      BrkSide      Feedr       Norm     1Fam
# 45     AllPub    Inside       Gtl      MeadowV       Norm       Norm    Twnhs
# 66     AllPub    Corner       Gtl        NAmes       Norm       Norm     1Fam
# 68     AllPub    Inside       Mod      Edwards       Norm       Norm     1Fam
# 105    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 109    AllPub    Inside       Gtl       Sawyer       Norm       Norm   Duplex
# 113    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 144    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam
# 152    AllPub    Inside       Gtl      OldTown      Feedr       Norm     1Fam
# 156    AllPub    Inside       Gtl      MeadowV       Norm       Norm   TwnhsE
# 180    AllPub    Inside       Gtl        SWISU      Feedr       Norm     1Fam
# 218    AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 230    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam
# 231    AllPub    Inside       Gtl      MeadowV       Norm       Norm   TwnhsE
# 256    AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 282    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 305    AllPub    Inside       Gtl       Sawyer       Norm       Norm     1Fam
# 314    AllPub    Inside       Gtl        SWISU       Norm       Norm   Duplex
# 320    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 337    AllPub    Inside       Gtl      OldTown     Artery       Norm     1Fam
# 341    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 350    AllPub    Corner       Gtl      OldTown      Feedr       Norm   2fmCon
# 359    AllPub    Corner       Gtl       IDOTRR     Artery       Norm     1Fam
# 395    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 482    AllPub    Inside       Gtl      MeadowV       Norm       Norm    Twnhs
# 496    AllPub    Inside       Gtl        SWISU       Norm       Norm   2fmCon
# 527    AllPub    Inside       Gtl      Edwards       Norm       Norm   Duplex
# 529    AllPub    Inside       Gtl      OldTown     Artery       Norm     1Fam
# 536    AllPub    Inside       Gtl      MeadowV       Norm       Norm    Twnhs
# 555    AllPub    Inside       Gtl      OldTown      Feedr       Norm     1Fam
# 566    AllPub    Inside       Gtl      SawyerW       RRAe       Norm     1Fam
# 591    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 596    AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 610    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam
# 615    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 618    AllPub    Corner       Gtl      Edwards       Norm       Norm   Duplex
# 629    AllPub    Inside       Gtl      SawyerW       RRAe       Norm     1Fam
# 674    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 698    AllPub    Inside       Gtl      Edwards       Norm       Norm   Duplex
# 711    AllPub    Inside       Gtl      OldTown       Norm       Norm   2fmCon
# 764    AllPub    Inside       Gtl      OldTown       Norm       Norm   2fmCon
# 779    AllPub    Inside       Gtl        SWISU       Norm       Norm   Duplex
# 803    AllPub    Inside       Gtl        SWISU       Norm       Norm     1Fam
# 813    AllPub    Inside       Gtl        NAmes       Norm       Norm   Duplex
# 859    AllPub    Corner       Gtl      Mitchel       Norm       Norm     1Fam
#
#     housestyle  overallqual  overallcond  yearbuilt  yearremod/add roofstyle  \
# 29      1.5Fin            3            5       1945           1950     Gable
# 45      2Story            4            6       1970           2008     Gable
# 66      1Story            4            4       1971           1971     Gable
# 68      1Story            3            6       1931           2006     Gable
# 105     1Story            5            9       1945           1997     Gable
# 109     1Story            4            3       1967           1967     Gable
# 113     1Story            5            5       2006           2006     Gable
# 144     1.5Fin            5            8       1947           1993     Gable
# 152     1.5Fin            6            7       1920           1998     Gable
# 156     2Story            4            4       1970           1970     Gable
# 180     1.5Fin            5            2       1931           1950     Gable
# 218     SFoyer            4            6       1923           1950       Hip
# 230     1Story            5            7       1940           2007      Flat
# 231     SFoyer            4            6       1972           1972     Gable
# 256     1.5Fin            4            7       1910           2004     Gable
# 282     1Story            5            5       1991           1992     Gable
# 305     1Story            5            3       1959           1959     Gable
# 314     2Story            4            6       1967           1967      Flat
# 320     1.5Fin            4            5       1947           1950     Gable
# 337     1.5Fin            4            7       1890           2006     Gable
# 341     1.5Fin            5            5       1910           1950     Gable
# 350     2.5Unf            7            5       1902           2000     Gable
# 359     1.5Fin            5            7       1919           2005     Gable
# 395     1Story            4            3       1910           1950     Gable
# 482     SFoyer            5            7       1970           1970     Gable
# 496     1.5Fin            5            4       1915           1950     Gable
# 527     1Story            5            5       1965           1965       Hip
# 529     1Story            2            5       1940           1950     Gable
# 536     2Story            4            5       1970           1970     Gable
# 555     1.5Unf            5            7       1930           1950     Gable
# 566     1Story            5            5       2004           2004     Gable
# 591     SFoyer            5            7       1971           1971     Gable
# 596     2Story            5            9       1905           2005     Gable
# 610     1.5Fin            5            7       1938           2007     Gable
# 615     1Story            2            3       1936           1950     Gable
# 618     1Story            4            3       1955           1955     Gable
# 629     1Story            6            5       2005           2006     Gable
# 674     SFoyer            5            5       1992           1992     Gable
# 698     SFoyer            5            5       1975           1975     Gable
# 711     2Story            4            5       1920           2008     Gable
# 764     2.5Unf            6            8       1910           1983     Gable
# 779     2Story            5            6       1923           1950       Hip
# 803     2Story            4            1       1907           1950   Gambrel
# 813     1Story            5            6       1962           2001       Hip
# 859     1Story            5            5       1985           1985     Gable
#
#     roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual  \
# 29   CompShg     MetalSd     MetalSd       None         0.0        TA
# 45   CompShg     CemntBd     CmentBd       None         0.0        TA
# 66   CompShg     HdBoard     HdBoard       None         0.0        TA
# 68   CompShg     MetalSd     MetalSd       None         0.0        TA
# 105  CompShg     VinylSd     VinylSd       None         0.0        TA
# 109  Tar&Grv     Plywood     Plywood    BrkFace        72.0        Fa
# 113  CompShg     VinylSd     VinylSd       None         0.0        TA
# 144  CompShg     MetalSd     MetalSd       None         0.0        TA
# 152  CompShg     MetalSd     MetalSd       None         0.0        TA
# 156  CompShg     CemntBd     CmentBd       None         0.0        TA
# 180  CompShg     VinylSd     VinylSd       None         0.0        TA
# 218  CompShg     MetalSd     MetalSd       None         0.0        TA
# 230  Tar&Grv     PreCast     PreCast       None         0.0        TA
# 231  CompShg     CemntBd     CmentBd       None         0.0        TA
# 256  CompShg     Wd Sdng     Wd Sdng       None         0.0        TA
# 282  CompShg     HdBoard     HdBoard       None         0.0        TA
# 305  CompShg     Wd Sdng     Plywood       None         0.0        TA
# 314  Tar&Grv     Plywood      CBlock       None         0.0        TA
# 320  CompShg     AsbShng     AsbShng       None         0.0        TA
# 337  CompShg     VinylSd     VinylSd       None         0.0        Gd
# 341  CompShg     MetalSd     MetalSd       None         0.0        TA
# 350  CompShg     MetalSd     MetalSd      Stone       188.0        TA
# 359  CompShg     CemntBd     CmentBd       None         0.0        TA
# 395  CompShg      Stucco      Stucco       None         0.0        TA
# 482  CompShg     CemntBd     CmentBd       None         0.0        TA
# 496  CompShg     Wd Sdng     Wd Shng       None         0.0        Fa
# 527  CompShg     AsphShn     AsphShn       None         0.0        TA
# 529  CompShg      Stucco      Stucco       None         0.0        Fa
# 536  CompShg     CemntBd     CmentBd       None         0.0        TA
# 555  CompShg     WdShing     Wd Sdng       None         0.0        TA
# 566  CompShg     VinylSd     VinylSd       None         0.0        TA
# 591  CompShg     Wd Sdng     HdBoard       None         0.0        TA
# 596  CompShg     MetalSd     MetalSd       None         0.0        Gd
# 610  CompShg     Wd Sdng     Wd Sdng       None         0.0        TA
# 615  CompShg     AsbShng     AsbShng       None         0.0        Fa
# 618  CompShg     AsbShng     Plywood     BrkCmn       128.0        TA
# 629  CompShg     VinylSd     VinylSd       None         0.0        TA
# 674  CompShg     HdBoard     Wd Shng       None         0.0        TA
# 698  CompShg     HdBoard     HdBoard       None         0.0        TA
# 711  CompShg     MetalSd     MetalSd       None         0.0        TA
# 764  CompShg     Wd Sdng     Wd Sdng       None         0.0        TA
# 779  CompShg     Wd Sdng     Plywood       None         0.0        TA
# 803  CompShg     Wd Sdng      Stucco       None         0.0        TA
# 813  CompShg     HdBoard     HdBoard    BrkFace       144.0        TA
# 859  CompShg     HdBoard     Plywood       None         0.0        TA
#
#     extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  \
# 29         TA     CBlock       TA       TA           No          LwQ
# 45         TA     CBlock       TA       TA           No          Unf
# 66         TA     CBlock       TA       TA           No          BLQ
# 68         TA     BrkTil       TA       TA           No          Rec
# 105        Gd     CBlock       TA       TA           No          ALQ
# 109        Fa     CBlock       TA       TA           No          ALQ
# 113        TA      PConc       Gd       TA           No          Unf
# 144        Gd       Slab      NaN      NaN          NaN          NaN
# 152        TA     BrkTil       TA       TA           No          Unf
# 156        TA     CBlock       TA       TA           No          Unf
# 180        TA      PConc       TA       Fa           No          Unf
# 218        Gd      PConc       Gd       Fa           Av          BLQ
# 230        TA      PConc       TA       TA           Gd          ALQ
# 231        TA     CBlock       Gd       TA           Av          LwQ
# 256        TA     BrkTil       TA       Fa           No          Unf
# 282        TA      PConc       Gd       TA           Mn          BLQ
# 305        TA     CBlock       TA       TA           No          GLQ
# 314        TA       Slab      NaN      NaN          NaN          NaN
# 320        TA       Slab      NaN      NaN          NaN          NaN
# 337        Gd     CBlock       Fa       TA           No          Unf
# 341        TA     BrkTil       Fa       TA           No          Unf
# 350        Fa     BrkTil       TA       Fa           No          Rec
# 359        TA     CBlock       TA       TA           No          Unf
# 395        TA     BrkTil       TA       TA           No          Unf
# 482        TA     CBlock       Gd       TA           Av          GLQ
# 496        Fa     BrkTil       TA       TA           No          Rec
# 527        TA     CBlock      NaN      NaN          NaN          NaN
# 529        TA      PConc       Fa       TA           No          Unf
# 536        TA     CBlock       TA       TA           No          Unf
# 555        Gd     BrkTil       TA       TA           No          LwQ
# 566        TA      PConc       Gd       TA           No          Unf
# 591        TA     CBlock       Gd       TA           Av          GLQ
# 596        TA     BrkTil       Fa       TA           No          Unf
# 610        TA      PConc       TA       TA           No          Unf
# 615        Fa     BrkTil       TA       Fa           No          Unf
# 618        TA      PConc      NaN      NaN          NaN          NaN
# 629        TA      PConc       Gd       TA           No          Unf
# 674        TA      PConc       Gd       TA           Av          GLQ
# 698        TA      PConc       Gd       TA           Av          GLQ
# 711        TA     BrkTil       TA       TA           No          Unf
# 764        TA      PConc       TA       TA           Mn          Rec
# 779        TA      PConc       TA       TA           Mn          Rec
# 803        TA     CBlock       TA       TA           No          Rec
# 813        TA     CBlock       TA       TA           No          BLQ
# 859        TA     CBlock       TA       TA           No          ALQ
#
#      bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating  \
# 29          144          Unf           0        226          370    GasA
# 45            0          Unf           0        546          546    GasA
# 66          614          Unf           0        244          858    GasA
# 68          544          Unf           0          0          544    GasA
# 105         329          Unf           0        357          686    GasA
# 109         704          Unf           0       1128         1832    GasA
# 113           0          Unf           0       1140         1140    GasA
# 144           0          NaN           0          0            0    GasA
# 152           0          Unf           0        901          901    GasA
# 156           0          Unf           0        546          546    GasA
# 180           0          Unf           0        894          894    GasA
# 218         749          Rec          63         46          858    GasA
# 230        1035          Unf           0        545         1580    GasA
# 231         150          GLQ         480          0          630    GasA
# 256           0          Unf           0        576          576    GasA
# 282         212          Unf           0        762          974    GasA
# 305         288          Unf           0        718         1006    GasA
# 314           0          NaN           0          0            0    GasA
# 320           0          NaN           0          0            0    GasA
# 337           0          Unf           0        925          925    GasA
# 341           0          Unf           0        801          801    GasA
# 350         169          Unf           0        851         1020    GasA
# 359           0          Unf           0        793          793    GasW
# 395           0          Unf           0        624          624    GasA
# 482         553          Unf           0         77          630    GasA
# 496        1026          Unf           0        186         1212    GasA
# 527           0          NaN           0          0            0    GasA
# 529           0          Unf           0        416          416    GasA
# 536           0          Unf           0        546          546    GasA
# 555         116          Unf           0        556          672    GasA
# 566           0          Unf           0       1114         1114    GasA
# 591         796          Unf           0          0          796    GasA
# 596           0          Unf           0        572          572    GasA
# 610           0          Unf           0        585          585    GasA
# 615           0          Unf           0        264          264    Grav
# 618           0          NaN           0          0            0    GasA
# 629           0          Unf           0       1131         1131    GasA
# 674         337          Unf           0        575          912    GasA
# 698         864          Unf           0          0          864    GasA
# 711           0          Unf           0        736          736    GasA
# 764         196          Unf           0       1046         1242    GasA
# 779         371          Unf           0        925         1296    Grav
# 803          73          Unf           0        634          707    GasW
# 813        1500          Unf           0        228         1728    GasA
# 859         625          Unf           0        208          833    GasA
#
#     heatingqc centralair electrical  1stflrsf  2ndflrsf  lowqualfinsf  \
# 29         TA          N      FuseA       442       228             0
# 45         TA          Y      SBrkr       798       546             0
# 66         TA          Y      SBrkr       858         0             0
# 68         Ex          Y      SBrkr       774         0             0
# 105        Gd          Y      SBrkr       866         0             0
# 109        TA          N      SBrkr      1832         0             0
# 113        Ex          Y      SBrkr      1140         0             0
# 144        Gd          Y      SBrkr       929       208             0
# 152        Gd          Y      SBrkr      1088       110             0
# 156        Ex          Y      SBrkr       546       546             0
# 180        Ex          Y      SBrkr       894       772             0
# 218        TA          Y      SBrkr       892         0             0
# 230        Ex          Y      SBrkr      1518         0             0
# 231        Ex          Y      SBrkr       630         0             0
# 256        Gd          Y      SBrkr       792       348             0
# 282        TA          Y      SBrkr       974         0             0
# 305        TA          Y      SBrkr      1006         0             0
# 314        TA          Y      SBrkr       862      1788             0
# 320        Gd          N      SBrkr       672       240             0
# 337        Gd          Y      SBrkr      1000       544             0
# 341        Gd          N      SBrkr       801       646             0
# 350        TA          N      FuseF       978       886             0
# 359        TA          N      FuseF       997       520             0
# 395        Ex          Y      SBrkr       816         0             0
# 482        Ex          Y      SBrkr       630         0             0
# 496        TA          N      SBrkr      1212       180             0
# 527        TA          N      SBrkr      1664         0             0
# 529        Gd          N      FuseA       599         0             0
# 536        TA          Y      SBrkr       546       546             0
# 555        Ex          Y      SBrkr       840         0             0
# 566        Ex          Y      SBrkr      1114         0             0
# 591        TA          Y      SBrkr       796         0             0
# 596        Ex          Y      SBrkr       884       656             0
# 610        Gd          Y      FuseF       585       468             0
# 615        Fa          N      FuseA       800         0             0
# 618        TA          N      SBrkr      1152         0             0
# 629        Ex          Y      SBrkr      1131         0             0
# 674        TA          Y      SBrkr       970         0             0
# 698        Fa          N      SBrkr       864         0             0
# 711        Gd          Y      SBrkr       736       716             0
# 764        Gd          Y      SBrkr      1242       742             0
# 779        Fa          N      FuseA      1296      1296             0
# 803        TA          N      SBrkr       942       942             0
# 813        TA          Y      SBrkr      1728         0             0
# 859        Ex          Y      SBrkr       833         0             0
#
#      grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  \
# 29         670             1             0         1         0             2
# 45        1344             0             0         1         1             3
# 66         858             0             0         1         0             3
# 68         774             0             0         1         0             3
# 105        866             0             0         1         0             2
# 109       1832             2             0         2         0             4
# 113       1140             0             0         1         0             3
# 144       1137             0             0         1         1             4
# 152       1198             0             0         1         0             4
# 156       1092             0             0         1         1             3
# 180       1666             1             0         1         0             3
# 218        892             1             0         1         0             1
# 230       1518             1             0         1         0             2
# 231        630             1             0         1         0             1
# 256       1140             0             0         1         0             3
# 282        974             0             0         1         0             3
# 305       1006             0             0         1         0             3
# 314       2650             0             0         3         0             6
# 320        912             0             0         1         0             2
# 337       1544             0             0         2         0             3
# 341       1447             0             0         1         0             3
# 350       1864             0             0         2         1             6
# 359       1517             0             0         2         0             3
# 395        816             0             0         1         0             2
# 482        630             1             0         1         0             1
# 496       1392             1             0         1         0             3
# 527       1664             0             0         2         0             4
# 529        599             1             0         1         0             2
# 536       1092             0             0         1         1             3
# 555        840             0             0         1         0             3
# 566       1114             0             0         1         1             3
# 591        796             0             1         1         0             2
# 596       1540             0             0         1         1             3
# 610       1053             0             0         1         1             2
# 615        800             0             0         1         0             1
# 618       1152             0             0         2         0             2
# 629       1131             0             0         1         1             3
# 674        970             0             1         1         0             3
# 698        864             1             0         1         0             2
# 711       1452             0             0         2         0             2
# 764       1984             0             0         2         0             5
# 779       2592             2             0         2         0             6
# 803       1884             0             0         1         1             4
# 813       1728             2             0         2         0             6
# 859        833             1             0         1         0             3
#
#      kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces  \
# 29              1          Fa             4        Typ           0
# 45              1          TA             6        Typ           1
# 66              1          TA             5        Typ           0
# 68              1          Gd             6        Typ           0
# 105             1          Gd             4        Typ           0
# 109             2          TA             8        Typ           0
# 113             1          TA             6        Typ           0
# 144             1          TA             8       Min1           0
# 152             1          TA             7        Typ           0
# 156             1          TA             5        Typ           0
# 180             1          TA             7        Typ           1
# 218             1          Gd             5       Min2           0
# 230             1          Fa             5        Typ           2
# 231             1          TA             3        Typ           0
# 256             1          TA             7       Min2           0
# 282             1          TA             5        Typ           0
# 305             1          TA             5        Typ           0
# 314             2          TA            10       Min2           0
# 320             1          TA             3        Typ           0
# 337             1          TA             7        Typ           0
# 341             1          TA             6        Typ           0
# 350             1          TA             9        Typ           0
# 359             1          Fa             7        Typ           0
# 395             1          TA             5        Typ           1
# 482             1          Ex             3        Typ           0
# 496             1          TA             6        Typ           0
# 527             2          TA             8        Typ           0
# 529             1          Gd             4        Typ           0
# 536             1          TA             5        Typ           0
# 555             1          TA             5        Typ           1
# 566             1          Gd             6        Typ           0
# 591             1          TA             5        Typ           0
# 596             1          Gd             7        Typ           0
# 610             1          Ex             5        Typ           0
# 615             1          Fa             4       Maj1           1
# 618             2          Fa             6        Typ           0
# 629             1          Gd             6        Typ           0
# 674             1          TA             6        Typ           0
# 698             1          TA             4        Typ           0
# 711             3          TA             8        Typ           0
# 764             1          TA             8        Typ           0
# 779             2          TA            12       Min2           0
# 803             1          TA             7        Typ           0
# 813             2          TA            10        Typ           0
# 859             1          TA             5        Typ           0
#
#     fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea  \
# 29           NA        NaN          NaN          NaN           0           0
# 45           TA        NaN          NaN          NaN           0           0
# 66           NA        NaN          NaN          NaN           0           0
# 68           NA        NaN          NaN          NaN           0           0
# 105          NA        NaN          NaN          NaN           0           0
# 109          NA        NaN          NaN          NaN           0           0
# 113          NA        NaN          NaN          NaN           0           0
# 144          NA        NaN          NaN          NaN           0           0
# 152          NA        NaN          NaN          NaN           0           0
# 156          NA        NaN          NaN          NaN           0           0
# 180          Gd        NaN          NaN          NaN           0           0
# 218          NA        NaN          NaN          NaN           0           0
# 230          Gd        NaN          NaN          NaN           0           0
# 231          NA        NaN          NaN          NaN           0           0
# 256          NA        NaN          NaN          NaN           0           0
# 282          NA        NaN          NaN          NaN           0           0
# 305          NA        NaN          NaN          NaN           0           0
# 314          NA        NaN          NaN          NaN           0           0
# 320          NA        NaN          NaN          NaN           0           0
# 337          NA        NaN          NaN          NaN           0           0
# 341          NA        NaN          NaN          NaN           0           0
# 350          NA        NaN          NaN          NaN           0           0
# 359          NA        NaN          NaN          NaN           0           0
# 395          Gd        NaN          NaN          NaN           0           0
# 482          NA        NaN          NaN          NaN           0           0
# 496          NA        NaN          NaN          NaN           0           0
# 527          NA        NaN          NaN          NaN           0           0
# 529          NA        NaN          NaN          NaN           0           0
# 536          NA        NaN          NaN          NaN           0           0
# 555          TA        NaN          NaN          NaN           0           0
# 566          NA        NaN          NaN          NaN           0           0
# 591          NA        NaN          NaN          NaN           0           0
# 596          NA        NaN          NaN          NaN           0           0
# 610          NA        NaN          NaN          NaN           0           0
# 615          Po        NaN          NaN          NaN           0           0
# 618          NA        NaN          NaN          NaN           0           0
# 629          NA        NaN          NaN          NaN           0           0
# 674          NA        NaN          NaN          NaN           0           0
# 698          NA        NaN          NaN          NaN           0           0
# 711          NA        NaN          NaN          NaN           0           0
# 764          NA     Detchd          NaN          NaN           1         360
# 779          NA        NaN          NaN          NaN           0           0
# 803          NA        NaN          NaN          NaN           0           0
# 813          NA        NaN          NaN          NaN           0           0
# 859          NA        NaN          NaN          NaN           0           0
#
#     garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  \
# 29         NaN        NaN          N           0           21              0
# 45         NaN        NaN          Y           0            0              0
# 66         NaN        NaN          Y           0            0              0
# 68         NaN        NaN          Y           0            0            286
# 105        NaN        NaN          Y          58           42              0
# 109        NaN        NaN          Y           0           58              0
# 113        NaN        NaN          Y          36           56              0
# 144        NaN        NaN          Y           0            0              0
# 152        NaN        NaN          N           0           98              0
# 156        NaN        NaN          Y           0            0              0
# 180        NaN        NaN          N           0          156              0
# 218        NaN        NaN          N           0            0            105
# 230        NaN        NaN          Y           0           39              0
# 231        NaN        NaN          Y          96           24              0
# 256        NaN        NaN          N           0          160              0
# 282        NaN        NaN          Y           0           28              0
# 305        NaN        NaN          Y           0           24              0
# 314        NaN        NaN          Y           0            0              0
# 320        NaN        NaN          N           0            0              0
# 337        NaN        NaN          N         231            0              0
# 341        NaN        NaN          N          80            0            244
# 350        NaN        NaN          N           0          188            102
# 359        NaN        NaN          N           0            0            144
# 395        NaN        NaN          N           0           33              0
# 482        NaN        NaN          Y           0            0              0
# 496        NaN        NaN          N           0            0            168
# 527        NaN        NaN          Y           0            0              0
# 529        NaN        NaN          N           0           81              0
# 536        NaN        NaN          Y           0           34              0
# 555        NaN        NaN          N           0            0              0
# 566        NaN        NaN          Y           0           39              0
# 591        NaN        NaN          Y         129            0              0
# 596        NaN        NaN          N         240           77              0
# 610        NaN        NaN          N          42            0              0
# 615        NaN        NaN          N           0            0              0
# 618        NaN        NaN          N           0            0              0
# 629        NaN        NaN          Y           0           39              0
# 674        NaN        NaN          Y          80           32              0
# 698        NaN        NaN          Y           0            0              0
# 711        NaN        NaN          N           0            0            102
# 764        NaN        NaN          Y          64            0            180
# 779        NaN        NaN          Y           0          742            240
# 803        NaN        NaN          N           0            0            239
# 813        NaN        NaN          Y           0            0              0
# 859        NaN        NaN          Y           0            0              0
#
#      3ssnporch  screenporch  poolarea  fence  miscval  mosold  yrsold
# 29           0            0         0  MnPrv     2000       7    2007
# 45           0            0         0    NaN        0       5    2009
# 66           0            0         0    NaN        0       6    2006
# 68           0            0         0    NaN        0       5    2007
# 105          0            0         0    NaN        0       8    2007
# 109          0            0         0    NaN        0       5    2010
# 113          0            0         0    NaN        0       7    2006
# 144          0            0         0    NaN        0       4    2008
# 152          0            0         0  MnPrv        0       9    2008
# 156          0            0         0    NaN        0       6    2010
# 180          0            0         0    NaN        0       5    2010
# 218          0          160         0    NaN        0       7    2009
# 230          0            0         0    NaN        0       1    2008
# 231          0            0         0    NaN        0       5    2010
# 256          0            0         0    NaN        0       6    2010
# 282          0            0         0  MnPrv        0       9    2007
# 305          0            0         0    NaN        0       7    2008
# 314          0            0         0    NaN      500       2    2010
# 320          0            0         0    NaN        0       7    2006
# 337          0            0         0    NaN        0       4    2007
# 341          0            0         0    NaN        0       7    2009
# 350          0            0         0    NaN        0       5    2009
# 359          0            0         0    NaN        0       8    2007
# 395          0            0         0    NaN        0       6    2009
# 482          0            0         0    NaN        0       8    2006
# 496          0            0         0    NaN        0       2    2010
# 527          0            0         0    NaN        0       5    2010
# 529          0            0         0    NaN        0       6    2009
# 536          0            0         0  GdPrv        0       6    2006
# 555          0            0         0    NaN        0       6    2007
# 566          0            0         0    NaN        0       8    2009
# 591          0            0         0   GdWo        0       9    2007
# 596          0            0         0    NaN        0       2    2008
# 610          0            0         0    NaN        0       1    2008
# 615          0            0         0    NaN        0       1    2009
# 618          0            0         0    NaN        0       9    2007
# 629          0            0         0    NaN        0       3    2006
# 674          0            0         0  MnPrv      700       7    2006
# 698          0            0         0    NaN        0       4    2008
# 711          0            0         0    NaN        0       6    2009
# 764          0            0         0  MnPrv     1000       9    2008
# 779          0            0         0    NaN     1512       1    2007
# 803          0            0         0    NaN        0       3    2010
# 813          0            0         0    NaN        0       1    2010
# 859          0            0         0  MnPrv        0       3    2009
#     mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour  \
# 29      sub050       RL    51.000000     3500   Pave      Reg         Lvl
# 45      sub160       RM    21.000000     1533   Pave      Reg         Lvl
# 66      sub020       RL    74.402570     8125   Pave      IR1         Lvl
# 68      sub030       RH    70.000000     4270   Pave      Reg         Bnk
# 105     sub030       RM    40.000000     3880   Pave      Reg         Lvl
# 109     sub090       RL    72.000000    10773   Pave      Reg         Lvl
# 113     sub020       RL    90.000000    17217   Pave      Reg         Lvl
# 144     sub050       RL    57.000000     8050   Pave      Reg         Lvl
# 152     sub050       RM    60.000000     5586   Pave      IR1         Bnk
# 156     sub160       RM    21.000000     1900   Pave      Reg         Lvl
# 180     sub050       RL    51.000000     9839   Pave      Reg         Lvl
# 218     sub085       RM    86.000000     5160   Pave      Reg         Lvl
# 230     sub030       RL    85.000000    19550   Pave      Reg         Lvl
# 231     sub180       RM    21.000000     1491   Pave      Reg         Lvl
# 256     sub050       RM    55.000000     8800   Pave      Reg         Lvl
# 282     sub020       RL    63.000000    10712   Pave      Reg         Lvl
# 305     sub020       RL    66.952061     9000   Pave      Reg         Lvl
# 314     sub090       RH    60.000000     7200   Pave      Reg         Lvl
# 320     sub050       RM    52.000000     6240   Pave      Reg         Lvl
# 337     sub050       RL    60.000000    14190   Pave      Reg         Lvl
# 341     sub050       RM    56.000000    10134   Pave      Reg         Lvl
# 350     sub190       RM    41.000000     5852   Pave      IR3         Bnk
# 359     sub050       RM    85.000000     8500   Pave      Reg         Lvl
# 395     sub030  C (all)    66.952061     3300   Pave      Reg         Lvl
# 482     sub180       RM    21.000000     1533   Pave      Reg         Lvl
# 496     sub190       RL    60.000000     9900   Pave      Reg         Lvl
# 527     sub090       RL    75.000000     9825   Pave      Reg         Lvl
# 529     sub030       RL    90.000000     5400   Pave      Reg         Lvl
# 536     sub160       RM    21.000000     1526   Pave      Reg         Lvl
# 555     sub045       RM    55.000000     4388   Pave      IR1         Bnk
# 566     sub020       RL    63.000000    13072   Pave      Reg         Lvl
# 591     sub085       RL    50.000000     6723   Pave      Reg         Lvl
# 596     sub070       RM    60.000000     6000   Pave      Reg         Lvl
# 610     sub050       RL    60.000000    12180   Pave      Reg         Lvl
# 615     sub030       RM    51.000000     6120   Pave      Reg         Lvl
# 618     sub090       RL    74.000000     6882   Pave      Reg         Lvl
# 629     sub020       RL    63.000000    13072   Pave      Reg         Lvl
# 674     sub085       RL    62.000000    10441   Pave      Reg         Lvl
# 698     sub090       RL    50.000000     9350   Pave      Reg         Lvl
# 711     sub190       RM    33.000000     4456   Pave      Reg         Lvl
# 764     sub060       RM    57.000000     8094   Pave      Reg         Lvl
# 779     sub090       RL    60.000000    10890   Pave      Reg         Lvl
# 803     sub070  C (all)    74.402570     6449   Pave      IR1         Lvl
# 813     sub090       RL    98.000000    13260   Pave      IR1         Lvl
# 859     sub020       RL    74.402570     8780   Pave      IR1         Lvl
#
#     utilities lotconfig landslope neighborhood condition1 condition2 bldgtype  \
# 29     AllPub    Inside       Gtl      BrkSide      Feedr       Norm     1Fam
# 45     AllPub    Inside       Gtl      MeadowV       Norm       Norm    Twnhs
# 66     AllPub    Corner       Gtl        NAmes       Norm       Norm     1Fam
# 68     AllPub    Inside       Mod      Edwards       Norm       Norm     1Fam
# 105    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 109    AllPub    Inside       Gtl       Sawyer       Norm       Norm   Duplex
# 113    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 144    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam
# 152    AllPub    Inside       Gtl      OldTown      Feedr       Norm     1Fam
# 156    AllPub    Inside       Gtl      MeadowV       Norm       Norm   TwnhsE
# 180    AllPub    Inside       Gtl        SWISU      Feedr       Norm     1Fam
# 218    AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 230    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam
# 231    AllPub    Inside       Gtl      MeadowV       Norm       Norm   TwnhsE
# 256    AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 282    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 305    AllPub    Inside       Gtl       Sawyer       Norm       Norm     1Fam
# 314    AllPub    Inside       Gtl        SWISU       Norm       Norm   Duplex
# 320    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 337    AllPub    Inside       Gtl      OldTown     Artery       Norm     1Fam
# 341    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 350    AllPub    Corner       Gtl      OldTown      Feedr       Norm   2fmCon
# 359    AllPub    Corner       Gtl       IDOTRR     Artery       Norm     1Fam
# 395    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam
# 482    AllPub    Inside       Gtl      MeadowV       Norm       Norm    Twnhs
# 496    AllPub    Inside       Gtl        SWISU       Norm       Norm   2fmCon
# 527    AllPub    Inside       Gtl      Edwards       Norm       Norm   Duplex
# 529    AllPub    Inside       Gtl      OldTown     Artery       Norm     1Fam
# ...
# 337       1544             0             0         2         0             3
# 341       1447             0             0         1         0             3
# 350       1864             0             0         2         1             6
# 359       1517             0             0         2         0             3
# 395        816             0             0         1         0             2
# 482        630             1             0         1         0             1
# 496       1392             1             0         1         0             3
# 527       1664             0             0         2         0             4
# 529        599             1             0         1         0             2
# 536       1092             0             0         1         1             3
# 555        840             0             0         1         0             3
# 566       1114             0             0         1         1             3
# 591        796             0             1         1         0             2
# 596       1540             0             0         1         1             3
# 610       1053             0             0         1         1             2
# 615        800             0             0         1         0             1
# 618       1152             0             0         2         0             2
# 629       1131             0             0         1         1             3
# 674        970             0             1         1         0             3
# 698        864             1             0         1         0             2
# 711       1452             0             0         2         0             2
# 764       1984             0             0         2         0             5
# 779       2592             2             0         2         0             6
# 803       1884             0             0         1         1             4
# 813       1728             2             0         2         0             6
# 859        833             1             0         1         0             3
#
#      kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces  \
# 29              1          Fa             4        Typ           0
# 45              1          TA             6        Typ           1
# 66              1          TA             5        Typ           0
# 68              1          Gd             6        Typ           0
# 105             1          Gd             4        Typ           0
# 109             2          TA             8        Typ           0
# 113             1          TA             6        Typ           0
# 144             1          TA             8       Min1           0
# 152             1          TA             7        Typ           0
# 156             1          TA             5        Typ           0
# 180             1          TA             7        Typ           1
# 218             1          Gd             5       Min2           0
# 230             1          Fa             5        Typ           2
# 231             1          TA             3        Typ           0
# 256             1          TA             7       Min2           0
# 282             1          TA             5        Typ           0
# 305             1          TA             5        Typ           0
# 314             2          TA            10       Min2           0
# 320             1          TA             3        Typ           0
# 337             1          TA             7        Typ           0
# 341             1          TA             6        Typ           0
# 350             1          TA             9        Typ           0
# 359             1          Fa             7        Typ           0
# 395             1          TA             5        Typ           1
# 482             1          Ex             3        Typ           0
# 496             1          TA             6        Typ           0
# 527             2          TA             8        Typ           0
# 529             1          Gd             4        Typ           0
# 536             1          TA             5        Typ           0
# 555             1          TA             5        Typ           1
# 566             1          Gd             6        Typ           0
# 591             1          TA             5        Typ           0
# 596             1          Gd             7        Typ           0
# 610             1          Ex             5        Typ           0
# 615             1          Fa             4       Maj1           1
# 618             2          Fa             6        Typ           0
# 629             1          Gd             6        Typ           0
# 674             1          TA             6        Typ           0
# 698             1          TA             4        Typ           0
# 711             3          TA             8        Typ           0
# 764             1          TA             8        Typ           0
# 779             2          TA            12       Min2           0
# 803             1          TA             7        Typ           0
# 813             2          TA            10        Typ           0
# 859             1          TA             5        Typ           0
#
#     fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea  \
# 29           NA        NaN          NaN          NaN           0           0
# 45           TA        NaN          NaN          NaN           0           0
# 66           NA        NaN          NaN          NaN           0           0
# 68           NA        NaN          NaN          NaN           0           0
# 105          NA        NaN          NaN          NaN           0           0
# 109          NA        NaN          NaN          NaN           0           0
# 113          NA        NaN          NaN          NaN           0           0
# 144          NA        NaN          NaN          NaN           0           0
# 152          NA        NaN          NaN          NaN           0           0
# 156          NA        NaN          NaN          NaN           0           0
# 180          Gd        NaN          NaN          NaN           0           0
# 218          NA        NaN          NaN          NaN           0           0
# 230          Gd        NaN          NaN          NaN           0           0
# 231          NA        NaN          NaN          NaN           0           0
# 256          NA        NaN          NaN          NaN           0           0
# 282          NA        NaN          NaN          NaN           0           0
# 305          NA        NaN          NaN          NaN           0           0
# 314          NA        NaN          NaN          NaN           0           0
# 320          NA        NaN          NaN          NaN           0           0
# 337          NA        NaN          NaN          NaN           0           0
# 341          NA        NaN          NaN          NaN           0           0
# 350          NA        NaN          NaN          NaN           0           0
# 359          NA        NaN          NaN          NaN           0           0
# 395          Gd        NaN          NaN          NaN           0           0
# 482          NA        NaN          NaN          NaN           0           0
# 496          NA        NaN          NaN          NaN           0           0
# 527          NA        NaN          NaN          NaN           0           0
# 529          NA        NaN          NaN          NaN           0           0
# 536          NA        NaN          NaN          NaN           0           0
# 555          TA        NaN          NaN          NaN           0           0
# 566          NA        NaN          NaN          NaN           0           0
# 591          NA        NaN          NaN          NaN           0           0
# 596          NA        NaN          NaN          NaN           0           0
# 610          NA        NaN          NaN          NaN           0           0
# 615          Po        NaN          NaN          NaN           0           0
# 618          NA        NaN          NaN          NaN           0           0
# 629          NA        NaN          NaN          NaN           0           0
# 674          NA        NaN          NaN          NaN           0           0
# 698          NA        NaN          NaN          NaN           0           0
# 711          NA        NaN          NaN          NaN           0           0
# 764          NA     Detchd          NaN          NaN           1         360
# 779          NA        NaN          NaN          NaN           0           0
# 803          NA        NaN          NaN          NaN           0           0
# 813          NA        NaN          NaN          NaN           0           0
# 859          NA        NaN          NaN          NaN           0           0
#
#     garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  \
# 29         NaN        NaN          N           0           21              0
# 45         NaN        NaN          Y           0            0              0
# 66         NaN        NaN          Y           0            0              0
# 68         NaN        NaN          Y           0            0            286
# 105        NaN        NaN          Y          58           42              0
# 109        NaN        NaN          Y           0           58              0
# 113        NaN        NaN          Y          36           56              0
# 144        NaN        NaN          Y           0            0              0
# 152        NaN        NaN          N           0           98              0
# 156        NaN        NaN          Y           0            0              0
# 180        NaN        NaN          N           0          156              0
# 218        NaN        NaN          N           0            0            105
# 230        NaN        NaN          Y           0           39              0
# 231        NaN        NaN          Y          96           24              0
# 256        NaN        NaN          N           0          160              0
# 282        NaN        NaN          Y           0           28              0
# 305        NaN        NaN          Y           0           24              0
# 314        NaN        NaN          Y           0            0              0
# 320        NaN        NaN          N           0            0              0
# 337        NaN        NaN          N         231            0              0
# 341        NaN        NaN          N          80            0            244
# 350        NaN        NaN          N           0          188            102
# 359        NaN        NaN          N           0            0            144
# 395        NaN        NaN          N           0           33              0
# 482        NaN        NaN          Y           0            0              0
# 496        NaN        NaN          N           0            0            168
# 527        NaN        NaN          Y           0            0              0
# 529        NaN        NaN          N           0           81              0
# 536        NaN        NaN          Y           0           34              0
# 555        NaN        NaN          N           0            0              0
# 566        NaN        NaN          Y           0           39              0
# 591        NaN        NaN          Y         129            0              0
# 596        NaN        NaN          N         240           77              0
# 610        NaN        NaN          N          42            0              0
# 615        NaN        NaN          N           0            0              0
# 618        NaN        NaN          N           0            0              0
# 629        NaN        NaN          Y           0           39              0
# 674        NaN        NaN          Y          80           32              0
# 698        NaN        NaN          Y           0            0              0
# 711        NaN        NaN          N           0            0            102
# 764        NaN        NaN          Y          64            0            180
# 779        NaN        NaN          Y           0          742            240
# 803        NaN        NaN          N           0            0            239
# 813        NaN        NaN          Y           0            0              0
# 859        NaN        NaN          Y           0            0              0
#
#      3ssnporch  screenporch  poolarea  fence  miscval  mosold  yrsold
# 29           0            0         0  MnPrv     2000       7    2007
# 45           0            0         0    NaN        0       5    2009
# 66           0            0         0    NaN        0       6    2006
# 68           0            0         0    NaN        0       5    2007
# 105          0            0         0    NaN        0       8    2007
# 109          0            0         0    NaN        0       5    2010
# 113          0            0         0    NaN        0       7    2006
# 144          0            0         0    NaN        0       4    2008
# 152          0            0         0  MnPrv        0       9    2008
# 156          0            0         0    NaN        0       6    2010
# 180          0            0         0    NaN        0       5    2010
# 218          0          160         0    NaN        0       7    2009
# 230          0            0         0    NaN        0       1    2008
# 231          0            0         0    NaN        0       5    2010
# 256          0            0         0    NaN        0       6    2010
# 282          0            0         0  MnPrv        0       9    2007
# 305          0            0         0    NaN        0       7    2008
# 314          0            0         0    NaN      500       2    2010
# 320          0            0         0    NaN        0       7    2006
# 337          0            0         0    NaN        0       4    2007
# 341          0            0         0    NaN        0       7    2009
# 350          0            0         0    NaN        0       5    2009
# 359          0            0         0    NaN        0       8    2007
# 395          0            0         0    NaN        0       6    2009
# 482          0            0         0    NaN        0       8    2006
# 496          0            0         0    NaN        0       2    2010
# 527          0            0         0    NaN        0       5    2010
# 529          0            0         0    NaN        0       6    2009
# 536          0            0         0  GdPrv        0       6    2006
# 555          0            0         0    NaN        0       6    2007
# 566          0            0         0    NaN        0       8    2009
# 591          0            0         0   GdWo        0       9    2007
# 596          0            0         0    NaN        0       2    2008
# 610          0            0         0    NaN        0       1    2008
# 615          0            0         0    NaN        0       1    2009
# 618          0            0         0    NaN        0       9    2007
# 629          0            0         0    NaN        0       3    2006
# 674          0            0         0  MnPrv      700       7    2006
# 698          0            0         0    NaN        0       4    2008
# 711          0            0         0    NaN        0       6    2009
# 764          0            0         0  MnPrv     1000       9    2008
# 779          0            0         0    NaN     1512       1    2007
# 803          0            0         0    NaN        0       3    2010
# 813          0            0         0    NaN        0       1    2010
# 859          0            0         0  MnPrv        0       3    2009

# %%
# The 114 rows with nulls in these columns represent less than 6% of garage-related data thus we will delete them
# drop rows where 'garagefinish','garagequal','garageyrblt','garagecond' is null
test.fillna(value=0, inplace=True)

# %%
# deal with nulls in masvnrarea
test.masvnrarea.fillna(value=0, inplace=True)

#check for changes
test['masvnrarea'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **Feature Engineering: variable ranking**

# %%
# define function to convert ranking to numerical form
def cond_to_numeric(x):
    if 'Ex' in x:
        return 5
    elif 'Gd' in x:
        return 4
    elif 'TA' in x:
        return 3
    elif 'Fa' in x:
        return 2
    elif 'Po':
        return 1
    else:
        return 0

# %%
# pass cond_to_numeric to convert data to numeric form
test['fireplacequ'] = test['fireplacequ'].map(cond_to_numeric)
test['extercond'] = test['extercond'].map(cond_to_numeric)
test['kitchenqual'] = test['kitchenqual'].map(cond_to_numeric)
test['heatingqc'] = test['heatingqc'].map(cond_to_numeric)

# %%
# calculate the mean QC score (Overall Quality/ Overall Condition) of properties in each neighborhood
qc_cols = ['overallqual', 'overallcond']

test.loc[:,'overall_qc'] = test.loc[:,qc_cols].mean(axis=1)

# rank the desirability of every neighbourhood by their median overall Quality/Condition
# step 1: perform groupby on neighborhood, then aggregate via taking median (as it's less affected by any outliers)
nb_qcscores = test.loc[:,['neighborhood','overall_qc']].groupby('neighborhood').agg('median')

# step 2: sort dataframe by descending order of the mean score
        #neighbourhood with higher overall QC --> assigned higher rank
nb_qcscores.sort_values(by='overall_qc', ascending=False, inplace=True)

# step 3: extract out neighborhood names from the index
nb_qcscores.loc[:,'neighborhood'] = nb_qcscores.index

# step 4: reset index to the usual numeric form
nb_qcscores.reset_index(drop=True, inplace=True)

#view neighbourhood ranked by score
nb_qcscores['neighborhood']
# Out:
# 0     Veenker
# 1     StoneBr
# 2     NridgHt
# 3     NoRidge
# 4      Greens
# 5      Timber
# 6     Crawfor
# 7     Blueste
# 8     Somerst
# 9     OldTown
# 10     NWAmes
# 11    Blmngtn
# 12    Gilbert
# 13    CollgCr
# 14    ClearCr
# 15    NPkVill
# 16    Mitchel
# 17     IDOTRR
# 18      SWISU
# 19    SawyerW
# 20    BrkSide
# 21     BrDale
# 22      NAmes
# 23    Edwards
# 24    MeadowV
# 25     Sawyer
# Name: neighborhood, dtype: object

# %%
# assign ordinal/numeric value to each neighborhood based on overall QC score
nrbrhd_rank = {'Veenker':1, 'Timber':2, 'StoneBr':3, 'Crawfor':4, 'NridgHt':5, 'NoRidge':6, 'Greens':7, 
               'Somerst':8, 'Blueste':9, 'SawyerW':10, 'NWAmes':11, 'NPkVill':12, 'Blmngtn':13,'GrnHill':14,
               'Gilbert':15, 'CollgCr':16, 'BrkSide':17, 'OldTown':18, 'ClearCr':19,'Landmrk':20, 'NAmes':21,
               'IDOTRR':22,'Edwards':23, 'SWISU':24,'Sawyer':25, 'BrDale':26, 'Mitchel':27, 'MeadowV':28}

test.replace({'neighborhood': nrbrhd_rank}, inplace=True)

# %%
test['neighborhood'].head()
# Out:
# 0    18
# 1    25
# 2    15
# 3    18
# 4    21
# Name: neighborhood, dtype: int64

# %%
# view unique values for housestyle
test['housestyle'].unique()
# Out:
# array(['2Story', '1Story', '1.5Fin', 'SLvl', 'SFoyer', '2.5Fin', '2.5Unf',
#        '1.5Unf'], dtype=object)

# %%
# assign ordinal/numeric value to each housestyle based on number of storeys/floors
    # less_2flrs = 1 = '1Story', '1.5Fin', 'SFoyer', 'SLvl', '1.5Unf'
    # atleast_2flrs = 2 = '2Story', '2.5Unf', '2.5Fin'
test["num_flrs"] = test["housestyle"].map(lambda x: 1 if x in ['1Story','1.5Fin', 'SFoyer', 'SLvl', '1.5Unf'] else 2)

test[["housestyle", "num_flrs"]].head(10)
# Out:
#   housestyle  num_flrs
# 0     2Story         2
# 1     1Story         1
# 2     2Story         2
# 3     1Story         1
# 4     1Story         1
# 5     2Story         2
# 6     1Story         1
# 7     1Story         1
# 8     2Story         2
# 9     1Story         1

# %%
# view unique values for garagefinish
test['garagefinish'].unique()
# Out:
# array(['Unf', 'Fin', 'RFn', 0], dtype=object)

# %%
# assign ordinal/numeric value to each garagefinish type
garagefin_rank = {'Fin': 1, 'RFn': 2, 'Unf': 3}

test.replace({'garagefinish': garagefin_rank}, inplace=True)

# %% [markdown]
# **Feature Engineering: dummify variables**

# %%
# show unique values for utilities column
display(test['utilities'].unique())
display(test['utilities'].describe())

# most houses have full set of utilities ('allpub')
display(test['utilities'].value_counts()['AllPub'])
display(test['utilities'].value_counts()['NoSewr'])

# as most houses have the full set, there is lack of variation for this feature
# we don't need to dummify 'utilities'
# Out:
# array(['AllPub', 'NoSewr'], dtype=object)
# count        878
# unique         2
# top       AllPub
# freq         877
# Name: utilities, dtype: object
# 877
# 1

# %%
# get dummies for lotshape, lotconfig
test = pd.get_dummies(test, columns = ['lotshape','lotconfig'], drop_first=True)

# %% [markdown]
# **Feature Engineering: modify variables**

# %%
# Create new variable: yrs_since_remod by subtracting yearremod/add from year 2022
test['yrs_since_remod'] = 2022 - test['yearremod/add']

# %%
# Create new variable: bathroooms by taking sum of fullbath + halfbath
test['bathrooms'] = test['fullbath'] + (0.5*test['halfbath'])
test['bathrooms'] .describe()
# Out:
# count    878.000000
# mean       1.739180
# std        0.652399
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.500000
# max        5.000000
# Name: bathrooms, dtype: float64

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Feature Selection is done by taking into account correlations of independent variables (features/ column names) with the dependent variable (sale price). I will consider only those variables with coefficients > 0.6 and < -0.6 that indicate strong positive correlation or strong negative correlation respectively.
#
# Based on the correlation score viewable in the heatmap below, I am positively selecting: 'neighborhood', 'overallqual', 'grlivarea', and 'garagearea'. I am rejecting 'totalbsmtsf' and'1stflrsf' as firstly, I am not including basement as part of total square footage, and secondly, '1stflrsf' is in fact, a subset of above grade living area.
#
# In addition, based on domain knowledge vis-à-vis Ames, Iowa gained by extensive external research, I am also positively selecting: 'garagefinish' as the average car ownership in Ames, Iowa is 2 cars per household which makes the finishing of the garage important, and 'num_flrs', as a sizeable portion of the population are family dwellings, hence household types are likely to influence preferred house types./'

# %% [markdown]
# **Finalise select features**

# %%
test = test[['neighborhood', 'overallqual', 'grlivarea', 'garagearea', 'garagefinish', 'num_flrs']]

# %% [markdown]
# # Saving cleaned Test dataset

# %%
# view columns in cleaned unseen/test set 
test.columns
# Out:
# Index(['neighborhood', 'overallqual', 'grlivarea', 'garagearea',
#        'garagefinish', 'num_flrs'],
#       dtype='object')

# %%
# view cleaned unseen/test set
pd.options.display.max_columns = None
test.head()
# Out:
#    neighborhood  overallqual  grlivarea  garagearea  garagefinish  num_flrs
# 0            18            6       1928         440             3         2
# 1            25            5       1967         580             1         1
# 2            15            7       1496         426             2         2
# 3            18            5        968         480             3         1
# 4            21            6       1394         514             2         1

# %%
# final check for nulls in cleaned unseen/test data
test.isnull().sum()
# Out:
# neighborhood    0
# overallqual     0
# grlivarea       0
# garagearea      0
# garagefinish    0
# num_flrs        0
# dtype: int64

# %%
test.shape
# Out:
# (878, 6)

# %%
# save data as csv files
test.to_csv('./data/test_cleaned.csv', index=False)
