# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# # Background
#
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. Test scores, as well as other metrics such as grade point average (GPA) and essay responses are used to determine a student's admission into a university.
#
# While standardized tests have long been a controversial topic for students, administrators, and legislators alike, it has been convention for students who are applying to university in the United States to present their test scores as measure of their college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)).

# %% [markdown]
# ## Problem Statement
#
# You work for the ACT inc, the board that administers an entrance exam used by most colleges and universities to make admissions decisions. <br>
#
# ACT inc has asked you to advise marketing decisions to high school students on sitting for the ACT should they intend to enrol in college for their intended school major. Since enrolling students can choose to sit for either the SAT or the ACT, the board is concerned about improving the ACT participation rates in the coming school year. <br>
#
# Your presentation and report should be geared toward non-technical executives of ACT inc and you will use the provided data and outside research to make recommendations about how the company might work to increase the participation rate in a state of your choice.

# %% [markdown]
# ## External Research
#
# In 2019, more than 1.72 million graduates (estimated 52% of the US high school graduands) sat for the ACT <a href="https://www.act.org/content/dam/act/unsecured/documents/National-CCCR-2019.pdf" target="_blank">(source)</a>.
# This is a slight drop from the 1.9 million ACT candidates (or estimated 55% of the graduating batch) reported in 2018. <a href="https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/" target="_blank">(source)</a>. Meanwhile, over 2.2 million graduates sat for the SAT, with a 4% increase from the previous year. <a href="https://newsroom.collegeboard.org/over-22-million-students-class-2019-took-sat-largest-group-ever" target="_blank">(source)</a>. Evidence here suggests that the ACT is becoming relatively less popular over the years.
#
# This can be traced to by the steady gain in market share by the College Board that owns the SAT, through "revising the test and entering into deals with numerous states and school systems to give students the exam" <a href="https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/" target="_blank">(source)</a>. Similar arrangements exist for the ACT as well, that allow students in said states and school systems to sit for the exam on a school day at no charge. As it stands, 16 states allow students to sit for the ACT exams at no charge, while 11 states offer students to sit for the SAT at no charge. <a href="https://www.collegeraptor.com/getting-in/articles/act-sat/states-act-sat-given-free/" target="_blank">(source)</a>.
#
# Applications to sit for the ACT and SAT cost a considerable sum. Self-sponsored ACT candidates pay \\$63 to sit for the exams, and an additional \\$25 to be tested on an optional Writing component. On the other hand, self-sponsored SAT candidates pay \\$60 to sit for the exams <a href="https://blog.prepscholar.com/act-vs-sat" target="_blank">(source)</a>.
#
# A strong factor that could influence participation rates are state education standards. While both ACT, inc and the College Board have acquired contracts to administer the respective exams in various states and school systems, some states have also made it compulsory for its high school graduades to sit for the affiliated exam as an exit test. <a href="https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act" target="_blank">(source)</a>.
#
# How prevalent is it that students sit for both tests? While colleges generally do not discriminate between the ACT and the SAT, a significant percentage of students sit for both exams <a href="https://www.princetonreview.com/college-advice/4-reasons-to-take-both-sat-and-act" target="_blank">(source)</a>. Among many reasons to sit for both exams include:
# - the ability to offer additional information on one's strengths to the Admissions Committe of one's intended college <a href="https://www.nytimes.com/2020/05/26/learning/should-students-be-required-to-take-the-sat-and-act-to-apply-to-college.html" target="_blank">(source)</a>,
#
# - being able to prepare more efficiently in the event that one is intending to re-sit either/both exams to earn target scores, and
# - increasing one's chances of earning merit-based financial aid upon enrolment to college <a href="https://www.princetonreview.com/college-advice/4-reasons-to-take-both-sat-and-act" target="_blank">(source)</a>.

# %% [markdown]
# ## Data Science workflow
#
# A data science workflow was undertaken to organise the processes for this project.
#
# Firstly, a problem statement was defined and established.
#
# Secondly, data from credible sources that contained suitable datasets were imported using Pandas. Appropriate datasets that were identified are: ACT participation rates and test scores from 2017 to 2019, as well as the SAT participation rates and test scores in 2019.
#
# Next, data cleaning was carried out to ensure that data is complete, in the correct formats and accurate. Upon cleaning, the various datasets were merged into a single DataFrame.
#
# Then, an exploratory data analysis was conducted to determine the trends over the years and to uncover any interesting insights across the datasets.
#
# Thereafter, data visualizations were plotted to highlight the trends and outliers about the populations.
#
# Finally, based on the analyses, recommendations were passed about how ACT inc can carry out a data-driven campaign to promote higher participation rates in its exams in the following years.

# %% [markdown]
# ## Data chosen for analysis
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
tst_values = [1,2,3,4,5]

# %%
def mean(values):
    res = sum(values)/len(values)
    return res

mean(tst_values)    #pass mean function into list titled tst_values
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def stdev(values):
    for v in values:   #for each value in the list of values
        sum_sq = 0        #find mean == mean(values)
        v_dev = v - mean(values)   #find each value's deviation from the mean
        sq_dev = (v_dev ** 2)    #square (each deviation from the mean)
        sum_sq += sq_dev #sum the square values
    standev = (sum_sq / len(values))** 0.5   #variance = sum_sq / N for population
    return standev                             #take sq_rt of variance

stdev(tst_values)   #pass stdev function into list titled tst_values
# Out:
# 0.8944271909999159

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
tst_string = "30.5%"

def num_to_float(pct_string):
    return float(pct_string.strip('%'))/100

num_to_float(tst_string)
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
act2017 = pd.read_csv('../data/act_2017.csv') 
act2017.head() #prints first 5 rows of act2017 dataframe
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act2018 = pd.read_csv('../data/act_2018.csv') 
act2018.head() #prints first 5 rows of act2018 dataframe
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act2019 = pd.read_csv('../data/act_2019.csv')
act2019.head() #prints first 5 rows of act2019 dataframe
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
sat2019 = pd.read_csv('../data/sat_2019.csv')
sat2019.head()   #prints first 5 rows of sat2019 dataframe
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#create a list of states where students can sit for ACT at no charge

states_act_free = [
    "Arkansas",
    "Louisiana",
    "North Carolina",
    "Alabama",
    "Wyoming",
    "Colorado",
    "Montana",
    "Utah",
    "Kentucky",
    "Nevada",
    "Wisconsin",
    "Missouri",
    "South Carolina",
    "Oklahoma",
    "Hawaii",
    "Mississippi"
]

states_act_free = sorted(states_act_free)
display(states_act_free)
display(len(states_act_free))

# Create a list of states where students can sit for SAT at no charge
states_sat_free = [
    "Michigan",
    "Connecticut",
    "New York",
    "Delaware",
    "Idaho",
    "New Hampshire",
    "Illinois",
    "Colorado",
    "Columbia",
    "Maine",
    "Rhode Island"
]

states_sat_free = sorted(states_sat_free)
display(states_sat_free)
display(len(states_sat_free))
# Out:
# ['Alabama',
#  'Arkansas',
#  'Colorado',
#  'Hawaii',
#  'Kentucky',
#  'Louisiana',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nevada',
#  'North Carolina',
#  'Oklahoma',
#  'South Carolina',
#  'Utah',
#  'Wisconsin',
#  'Wyoming']
# 16
# ['Colorado',
#  'Columbia',
#  'Connecticut',
#  'Delaware',
#  'Idaho',
#  'Illinois',
#  'Maine',
#  'Michigan',
#  'New Hampshire',
#  'New York',
#  'Rhode Island']
# 11

# %%
#find out if there are any states that offer both the SAT and ACT for free

list(set(states_act_free).intersection(set(states_sat_free)))
# Out:
# ['Colorado']

# %%
is_free = pd.read_csv('../data/act_sat_free.csv')     #reads is_free as pandas dataframe
is_free.head()           #prints first 5 rows of is_free dataframe
# Out:
#         state  act_free  sat_free
# 0     Alabama         1         0
# 1      Alaska         0         0
# 2     Arizona         0         0
# 3    Arkansas         1         0
# 4  California         0         0

# %% [markdown]
# #### 2. Check for missing values.

# %%
display(act2017.isnull().values.any()) #checks for any null/blanks in act2017 dataframe
display(act2018.isnull().values.any()) #checks for any null/blanks in act2018 dataframe
display(act2019.isnull().values.any()) #checks for any null/blanks in act2019 dataframe
display(sat2019.isnull().values.any()) #checks for any null/blanks in sat2019 dataframe
# Out:
# False
# False
# False
# False

# %% [markdown]
# #### 3. Check for any obvious issues with the observations.

# %% [markdown]
# To find minimum and maximum values, data must be in numerical format- int or float. <br>
# However, the data for participation and scores were not formatted correctly in the datasets.<br>
# These data points are converted to correct formats later in step 6 and the columns are renamed in step 7.<br>
# The values in these columns are also checked against minimum and maximum possible values in step 7.

# %%
display(act2017.describe())
display(act2018.describe())
display(act2019.describe())
display(sat2019.describe())
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# ...

# %% [markdown]
# #### 4. Fix any errors you identified in steps 2-3.

# %%
# remove rows in sat2019 for Virgin Islands and Puerto Rico where values are input as "-"

sat2019 = sat2019.loc[sat2019["Participation Rate"] != "—" ]   
sat2019.tail()
# Out:
#             State Participation Rate  EBRW  Math  Total
# 48       Virginia                68%   567   551   1119
# 49     Washington                70%   539   535   1074
# 50  West Virginia                99%   483   460    943
# 51      Wisconsin                 3%   635   648   1283
# 52        Wyoming                 3%   623   615   1238

# %% [markdown]
# #### 5. Display the data types of each feature.

# %%
act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
act2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act2019.dtypes           #presents data types present in act2019 dataframe
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
sat2019.dtypes          #presents data types present in sat2019 dataframe
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %% [markdown]
# #### 6. Fix any incorrect data types found in step 5.

# %%
# assigns correct value '20.2' instead of '20.2x' to act2017['Composite'][51]
act2017['Composite'][51] = 20.2

# change datatype of 'Composite' column in act2017
act2017['Composite'] = act2017['Composite'].apply(pd.to_numeric)

# change the datatype of 'Participation' column in act2017
act2017['Participation'] = act2017.Participation.apply(num_to_float)
# Out:
# /var/folders/n2/ln256wq518d5zk05dzh0wrsw0000gn/T/ipykernel_77265/2750500096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   act2017['Composite'][51] = 20.2

# %%
# delete duplicate row in act2018
act2018 = act2018.drop_duplicates(subset=['State']) 

# reset index from 0 in act2018
act2018.reset_index(drop=True, inplace=True)

# change the datatype of 'Participation' col in act2018
act2018['Participation'] = act2018.Participation.apply(num_to_float)

# %%
# change the datatype of 'Participation' column in act2019 
act2019['Participation'] = act2019.Participation.apply(num_to_float)

# %%
# change the datatype of 'Participation Rate' column in sat2019 
sat2019['Participation Rate'] = sat2019['Participation Rate'].apply(num_to_float)

# %% [markdown]
# #### 7. Rename Columns.

# %%
# remove unnecessary columns
act2017.drop(['English','Math','Reading','Science'], axis=1, inplace=True)

# rename act2017 columns to lowercase, without space, using informative terms
act2017.rename(columns={"State": "state", "Participation": "act17_part_rate", "Composite": "act17_com_score"}, inplace=True)

act2017.tail()
# Out:
#             state  act17_part_rate  act17_com_score
# 47       Virginia             0.29             23.8
# 48     Washington             0.29             21.9
# 49  West Virginia             0.69             20.4
# 50      Wisconsin             1.00             20.5
# 51        Wyoming             1.00             20.2

# %%
# rename act2018 columns to lowercase, without space, informative terms
act2018.rename(columns={"State": "state", "Participation": "act18_part_rate", "Composite": "act18_com_score"}, inplace=True)

act2018.tail()
# Out:
#             state  act18_part_rate  act18_com_score
# 46       Virginia             0.24             23.9
# 47     Washington             0.24             22.2
# 48  West Virginia             0.65             20.3
# 49      Wisconsin             1.00             20.5
# 50        Wyoming             1.00             20.0

# %%
# rename act2019 columns to lowercase, without space, using informative terms
act2019.rename(columns={"State": "state", "Participation": "act19_part_rate", "Composite": "act19_com_score"}, inplace=True)

act2019.tail()
# Out:
#             state  act19_part_rate  act19_com_score
# 47     Washington             0.24             22.1
# 48  West Virginia             0.49             20.8
# 49      Wisconsin             1.00             20.3
# 50        Wyoming             1.00             19.8
# 51       National             0.52             20.7

# %%
# remove unnecessary columns
sat2019.drop(['EBRW','Math'], axis=1, inplace=True)

# renames sat2019 columns to lowercase, without space, using informative terms
sat2019.rename(columns={"State": "state", "Participation Rate": "sat19_part_rate", "Total": "sat19_total_score"}, inplace=True)

# %% [markdown]
# #### 8. Perform any additional cleaning that you feel is necessary.

# %%
# rename 'District of columbia' in act2018
act2018['state'][8] = "District of Columbia"

act2018.head(10)
# Out:
# /var/folders/n2/ln256wq518d5zk05dzh0wrsw0000gn/T/ipykernel_77265/1466736712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   act2018['state'][8] = "District of Columbia"
#                   state  act18_part_rate  act18_com_score
# 0               Alabama             1.00             19.1
# 1                Alaska             0.33             20.8
# 2               Arizona             0.66             19.2
# 3              Arkansas             1.00             19.4
# 4            California             0.27             22.7
# 5              Colorado             0.30             23.9
# 6           Connecticut             0.26             25.6
# 7              Delaware             0.17             23.8
# 8  District of Columbia             0.32             23.6
# ...

# %% [markdown]
# ##### Adding new columns to dataframe to compare state's performance against national mean

# %%
# calculate what is national mean for ACT participation rate in 2019
act19_part_mean = mean(act2019['act19_part_rate'])
act19_part_mean
# Out:
# 0.5853846153846154

# %%
# create new column to show how each state's ACT participation compares to national mean
act2019['act19_part_pct_change'] =  (act2019['act19_part_rate'] - act19_part_mean)/(act19_part_mean)

# %%
# calculate what is national mean for ACT composite score in 2019
act19_score_mean = mean(act2019['act19_com_score'])
act19_score_mean
# Out:
# 21.449999999999992

# %%
# create new column to show how each state's ACT composite score compares to national mean
act2019['act19_score__pct_change'] =  (act2019['act19_com_score'] - act19_score_mean)/(act19_score_mean)

# %% [markdown]
# ##### How much does each state deviate from the SAT national mean for participation and score?

# %%
# calculate what is national mean for SAT participation rate in 2019
sat19_part_mean = mean(sat2019['sat19_part_rate'])
sat19_part_mean
# Out:
# 0.49058823529411755

# %%
# create new column to show how each state's SAT participation compares to national mean
sat2019['sat19_part_pct_change'] =  (sat2019['sat19_part_rate'] - sat19_part_mean)/(sat19_part_mean)

# %%
# calculate what is national mean for SAT total score in 2019
sat19_score_mean = mean(sat2019['sat19_total_score'])
display(sat19_score_mean)
# Out:
# 1113.078431372549

# %%
# create new column to show how each state's SAT average total score compares to national mean
sat2019['sat19_score_pct_change'] =  (sat2019['sat19_total_score'] - sat19_score_mean)/(sat19_score_mean)

# %% [markdown]
# #### 9. Drop unnecessary rows (if needed).

# %%
# drop first row in act2017 that contains national statistics
act2017 = act2017[1:]

# reset index from 0 in act2017
act2017.reset_index(drop=True, inplace=True)

# %%
# drop last row in act2019 that contains national statistics
act2019 = act2019[:-1]
act2019.tail()
# Out:
#             state  act19_part_rate  act19_com_score  act19_part_pct_change  \
# 46       Virginia             0.21             24.0              -0.641261
# 47     Washington             0.24             22.1              -0.590013
# 48  West Virginia             0.49             20.8              -0.162943
# 49      Wisconsin             1.00             20.3               0.708279
# 50        Wyoming             1.00             19.8               0.708279
#
#     act19_score__pct_change
# 46                 0.118881
# 47                 0.030303
# 48                -0.030303
# 49                -0.053613
# 50                -0.076923

# %%
# reset index from 0 in sat2019
sat2019.reset_index(drop=True, inplace=True)

sat2019.tail()
# Out:
#             state  sat19_part_rate  sat19_total_score  sat19_part_pct_change  \
# 46       Virginia             0.68               1119               0.386091
# 47     Washington             0.70               1074               0.426859
# 48  West Virginia             0.99                943               1.017986
# 49      Wisconsin             0.03               1283              -0.938849
# 50        Wyoming             0.03               1238              -0.938849
#
#     sat19_score_pct_change
# 46                0.005320
# 47               -0.035108
# 48               -0.152800
# 49                0.152659
# 50                0.112231

# %% [markdown]
# #### 10. Merge dataframes that can be merged.

# %%
# merge all the data sets
df_0 = pd.merge(act2017, act2018, on='state', how='outer')
df_1 = pd.merge(df_0, is_free[['state','act_free']], on='state', how='outer')
df_2 = pd.merge(df_1, act2019, on='state', how='outer')
df_3 = pd.merge(df_2, is_free[['state','sat_free']], on='state', how='outer')
df_final = pd.merge(df_3, sat2019, on='state', how='outer')

df_final.head()
# Out:
#         state  act17_part_rate  act17_com_score  act18_part_rate  \
# 0     Alabama             1.00             19.2             1.00
# 1      Alaska             0.65             19.8             0.33
# 2     Arizona             0.62             19.7             0.66
# 3    Arkansas             1.00             19.4             1.00
# 4  California             0.31             22.8             0.27
#
#    act18_com_score  act_free  act19_part_rate  act19_com_score  \
# 0             19.1         1             1.00             18.9
# 1             20.8         0             0.38             20.1
# 2             19.2         0             0.73             19.0
# 3             19.4         1             1.00             19.3
# 4             22.7         0             0.23             22.6
#
#    act19_part_pct_change  act19_score__pct_change  sat_free  sat19_part_rate  \
# 0               0.708279                -0.118881         0             0.07
# ...

# %% [markdown]
# #### 11. Save your cleaned and merged dataframes as csv files.

# %%
df_final.to_csv('final_csv.csv', index=False)

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**act_free**|bool|final_csv|Expresses whether students in a state can take the ACT for free. 1= True, 0= False|
# |**act17_part_rate** **act18_part_rate** **act19_part_rate** |*float*|final_csv|ACT participation rate (in percentage) in a given year. 0.22 means 22%|
# |**act_com_score**|*float*|final_csv|ACT Composite score for a given state in a given year. act17_com_score refers to the composite score in the year 2017. (Possible score range 1-36)|
# |**part_pct_change**|*float*|final_csv|State participation in a given exam as percentage of national average participation|
# |**sat_free**|*bool*|final_csv|Expresses whether students in a state can take the SAT for free. 1= True, 0= False|
# |**sat19_part_rate**|*float*|final_csv|SAT participation rate (in percentage) in the year 2019. 0.22 means 22%|
# |**sat19_total_score**|*float*|final_csv|Average total score for a given state in the year 2019, computed using EWR and Math scores (Possible score range 400-1600)|
# |**score_pct_change**|*float*|final_csv|State average score in a given exam as percentage of national average score|
# |**state**|*object*|final_csv|Names of all US states and the District of Columbia|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# #### 1. Summary Statistics.

# %%
df_final.describe()
# Out:
#        act17_part_rate  act17_com_score  act18_part_rate  act18_com_score  \
# count        51.000000        51.000000        51.000000        51.000000
# mean          0.652549        21.519608         0.617255        21.496078
# std           0.321408         2.020695         0.340371         2.111583
# min           0.080000        17.800000         0.070000        17.700000
# 25%           0.310000        19.800000         0.285000        19.950000
# 50%           0.690000        21.400000         0.660000        21.300000
# 75%           1.000000        23.600000         1.000000        23.650000
# max           1.000000        25.500000         1.000000        25.600000
#
#         act_free  act19_part_rate  act19_com_score  act19_part_pct_change  \
# count  51.000000        51.000000        51.000000              51.000000
# mean    0.294118         0.586667        21.464706               0.002190
# std     0.460179         0.345159         2.194523               0.589628
# ...

# %% [markdown]
# #### 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  <br> **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# Applies stdev function using dictionary comprehension to each numeric column 
## in combined 2019 ACT/SAT dataframe, excludes 'state' column

df_final_sd = {col:stdev(df_final[col]) for col in df_final.columns if col != 'state'}
df_final_sd
# Out:
# {'act17_part_rate': 0.04865286880191439,
#  'act17_com_score': 0.1847820581472257,
#  'act18_part_rate': 0.053595033804366185,
#  'act18_com_score': 0.20949288315948458,
#  'act_free': 0.09884330004903598,
#  'act19_part_rate': 0.05787824347315774,
#  'act19_com_score': 0.2331054492823088,
#  'act19_part_pct_change': 0.09887216362037458,
#  'act19_score__pct_change': 0.0108673869129282,
#  'sat_free': 0.030202119459427666,
#  'sat19_part_rate': 0.06449525328199597,
#  'sat19_total_score': 17.492518461455795,
#  'sat19_part_pct_change': 0.13146514457960815,
#  'sat19_score_pct_change': 0.015715441040291808}

# %% [markdown]
# #### 3. Investigate trends in the data.

# %%
# Calculates highest participation rate for ACT in 2019
display(df_final['act19_part_rate'].max())

# Filters states which have highest ACT participation rate in 2019
actpart_is_top = (df_final['act19_part_rate'] == 1.00)
highest_actpart = df_final[actpart_is_top]
display(highest_actpart)
# Out:
# 1.0
#              state  act17_part_rate  act17_com_score  act18_part_rate  \
# 0          Alabama             1.00             19.2              1.0
# 3         Arkansas             1.00             19.4              1.0
# 17        Kentucky             1.00             20.0              1.0
# 18       Louisiana             1.00             19.5              1.0
# 24     Mississippi             1.00             18.6              1.0
# 26         Montana             1.00             20.3              1.0
# 27        Nebraska             0.84             21.4              1.0
# 28          Nevada             1.00             17.8              1.0
# 33  North Carolina             1.00             19.1              1.0
# 35            Ohio             0.75             22.0              1.0
# 36        Oklahoma             1.00             19.4              1.0
# 42       Tennessee             1.00             19.8              1.0
# ...

# %%
# Calculates highest participation rate for SAT in 2019
display(df_final['sat19_part_rate'].max())

# Filters states which have highest SAT participation rate in 2019
satpart_is_top = (df_final['sat19_part_rate'] == 1.00)

highest_satpart = df_final[satpart_is_top]
display(highest_satpart)
# Out:
# 1.0
#            state  act17_part_rate  act17_com_score  act18_part_rate  \
# 5       Colorado             1.00             20.8             0.30
# 6    Connecticut             0.31             25.2             0.26
# 7       Delaware             0.18             24.1             0.17
# 9        Florida             0.73             19.8             0.66
# 12         Idaho             0.38             22.3             0.36
# 13      Illinois             0.93             21.4             0.43
# 22      Michigan             0.29             24.1             0.22
# 39  Rhode Island             0.21             24.0             0.15
#
#     act18_com_score  act_free  act19_part_rate  act19_com_score  \
# 5              23.9         1             0.27             23.8
# 6              25.6         0             0.22             25.5
# 7              23.8         0             0.13             24.1
# 9              19.9         0             0.54             20.1
# ...

# %% [markdown]
# #### Highest participation rates in ACT and SAT in year 2019
# The highest participation rate for ACT in 2019 was 100%. This statistic was reported in: Alabama, Arkansas, Kentucky, Louisiana, Mississippi, Montana, Nebraska, Nevada, North Carolina, Ohio, Oklahoma, Tennessee, Utah, Wisconsin, Wyoming.
#
# The highest participation rate for SAT in 2019 was 100%. This statistic was reported in: Colorado, Connecticut, Delaware, Florida, Idaho, Illinois, Michigan and Rhode Island.

# %%
# Sorts for states with lowest ACT participation rate in 2019, in alphabetical order
lowest_actpart = df_final.sort_values(by='act19_part_rate', ascending=True).head()
lowest_actpart.sort_values(by='state', ascending=True).head()

## Alternatively, to show lowest part rates, not in alphabetical order:
# act2019.sort_values(by='part_rate', ascending=True).head()
# Out:
#             state  act17_part_rate  act17_com_score  act18_part_rate  \
# 7        Delaware             0.18             24.1             0.17
# 19          Maine             0.08             24.3             0.07
# 29  New Hampshire             0.18             25.5             0.16
# 38   Pennsylvania             0.23             23.7             0.20
# 39   Rhode Island             0.21             24.0             0.15
#
#     act18_com_score  act_free  act19_part_rate  act19_com_score  \
# 7              23.8         0             0.13             24.1
# 19             24.0         0             0.06             24.3
# 29             25.1         0             0.14             25.0
# 38             23.5         0             0.17             23.6
# 39             24.2         0             0.12             24.7
#
#     act19_part_pct_change  act19_score__pct_change  sat_free  sat19_part_rate  \
# 7               -0.777924                 0.123543         1             1.00
# ...

# %%
# Sorts for states with lowest SAT participation rate in 2019, in alphabetical order
lowest_satpart = df_final.sort_values(by='sat19_part_rate', ascending=True).head()
lowest_satpart.sort_values(by='state', ascending=True).head()

## Alternatively, to show lowest part rates, not in alphabetical order:
# sat2019.sort_values(by='part_rate', ascending=True).head()
# Out:
#            state  act17_part_rate  act17_com_score  act18_part_rate  \
# 27      Nebraska             0.84             21.4             1.00
# 34  North Dakota             0.98             20.3             0.98
# 41  South Dakota             0.80             21.8             0.77
# 49     Wisconsin             1.00             20.5             1.00
# 50       Wyoming             1.00             20.2             1.00
#
#     act18_com_score  act_free  act19_part_rate  act19_com_score  \
# 27             20.1         0             1.00             20.0
# 34             20.3         0             0.96             19.9
# 41             21.9         0             0.75             21.6
# 49             20.5         1             1.00             20.3
# 50             20.0         1             1.00             19.8
#
#     act19_part_pct_change  act19_score__pct_change  sat_free  sat19_part_rate  \
# 27               0.708279                -0.067599         0             0.03
# ...

# %% [markdown]
# #### Lowest participation rates in ACT and SAT in year 2019
# Lowest 5 ACT participation rates were reported in: Maine, Rhode Island, Delaware, New Hampshire and Pennsylvania, with participation rates falling below 5%.
#
# Concurrently, lowest 5 SAT participation rates were reported in: North Dakota, Wyoming, South Dakota, Nebraska and Wisconsin.

# %%
# Filters for states with top composite scores in ACT 2019, sorted alphabetically
highest_actscore = df_final.sort_values(by='act19_com_score', ascending=False).head()
highest_actscore.sort_values(by='state', ascending=True).head()
# Out:
#             state  act17_part_rate  act17_com_score  act18_part_rate  \
# 6     Connecticut             0.31             25.2             0.26
# 21  Massachusetts             0.29             25.4             0.25
# 29  New Hampshire             0.18             25.5             0.16
# 32       New York             0.31             24.2             0.27
# 39   Rhode Island             0.21             24.0             0.15
#
#     act18_com_score  act_free  act19_part_rate  act19_com_score  \
# 6              25.6         0             0.22             25.5
# 21             25.5         0             0.21             25.5
# 29             25.1         0             0.14             25.0
# 32             24.5         0             0.22             24.5
# 39             24.2         0             0.12             24.7
#
#     act19_part_pct_change  act19_score__pct_change  sat_free  sat19_part_rate  \
# 6               -0.624179                 0.188811         1             1.00
# ...

# %%
# Filters for states with top total scores in SAT 2019, sorted alphabetically
highest_satscore = df_final.sort_values(by='sat19_total_score', ascending=False).head()
highest_satscore.sort_values(by='state', ascending=True).head()
# Out:
#            state  act17_part_rate  act17_com_score  act18_part_rate  \
# 23     Minnesota             1.00             21.5             0.99
# 27      Nebraska             0.84             21.4             1.00
# 34  North Dakota             0.98             20.3             0.98
# 41  South Dakota             0.80             21.8             0.77
# 49     Wisconsin             1.00             20.5             1.00
#
#     act18_com_score  act_free  act19_part_rate  act19_com_score  \
# 23             21.3         0             0.95             21.4
# 27             20.1         0             1.00             20.0
# 34             20.3         0             0.96             19.9
# 41             21.9         0             0.75             21.6
# 49             20.5         1             1.00             20.3
#
#     act19_part_pct_change  act19_score__pct_change  sat_free  sat19_part_rate  \
# 23               0.622865                -0.002331         0             0.04
# ...

# %% [markdown]
# #### States with highest average scores in ACT and SAT in 2019
#
# States that reported highest average scores in ACT: Massachusetts, Connecticut, New Hampshire, Rhode Island and New York.
#
# States that reported highest average scores in SAT: Minnesota, Wisconsin, South and North Dakota and Nebraska.

# %% [markdown]
# ## Data visualisation

# %%
# show relationship between having to pay for ACT and turnout 
fig1 = df_final.groupby('act_free')['act19_part_rate'].mean().plot(kind='bar')

# set the title
fig1.set_title('Is ACT participation rate affected by financial cost of exams?', fontsize=18, y=1.01)

# save plot
plt.savefig('barg_act19_partfree',bbox_inches = 'tight')

# %%
# show relationship between having to pay for SAT and turnout 
fig2 = df_final.groupby('sat_free')['sat19_part_rate'].mean().plot(kind='bar')

# set the title
fig2.set_title('Is SAT participation rate affected by financial cost of exams?', fontsize=18, y=1.01)

# save plot
plt.savefig('barg_sat19_partfree',bbox_inches = 'tight')

# %% [markdown]
# ##### Relationship between having to bear cost of ACT/SAT fees in a state and its participation rate
#
# fig1 shows that ACT participation rates were higher in states that offered the exams at no charge to its students, whereas ACT participation rates were lower in states where students had to bear the cost of the exam fees.<br>
#
# Similarly for the SAT, fig2 shows that participation rates were higher in states that offered the exams at no charge to its students than in states where students had to bear the cost of the exam fees.
#
# However, it should be noted that on average, SAT participation rates outstrips ACT participation rates in the states that offer the respective exams at no charge.

# %%
# define function to plot seaborn scatter plot
def sns_scatter(df, var_1, var_2, x_label, y_label, fig_title):

    fig = sns.lmplot(x=var_1, y=var_2, data=df_final, height=6,)

    
    plt.title(fig_title, fontsize=18)
    plt.xlabel(x_label, fontsize=14)
    plt.ylabel(y_label, fontsize=14)
    
    corr_val = df_final[var_1].corr(df_final[var_2])
    
    print("Correlation between {} and {} is: {}.".format(var_1, var_2, corr_val))

# %%
sns_scatter(
    df_final,
    "sat19_part_rate", 
    "act19_part_rate",
    "SAT 2019 participation rate",
    "ACT 2019 participation rate",
    "How are ACT participation correlated with SAT participation in 2019?"
    )

plt.savefig('scatter_act_sat_part',bbox_inches = 'tight')
# Out:
# Correlation between sat19_part_rate and act19_part_rate is: -0.8654353036794787.

# %% [markdown]
# ##### Relationship between ACT participation rates and SAT participation rates in 2019
# There is a negative correlation between ACT participation rates and SAT participation rates. From the spread of the scatter plot, most states where there is high ACT participation report very low SAT participation concurrently. Conversely, in most states where there is high SAT participation, there is also a higher number of students who sat for the ACT as well.

# %%
sns_scatter(
    df_final,
    "act19_part_rate", 
    "act19_com_score",
    "ACT 2019 participation rate",
    "ACT 2019 composite score",
    "How are ACT scores correlated with its participation rate?"
    )

plt.savefig('scatter_act19_scorepart', bbox_inches = 'tight')
# Out:
# Correlation between act19_part_rate and act19_com_score is: -0.8668191877685284.

# %% [markdown]
# ##### Relationship between each state's ACT participation rate and its average composite score
# There is a negative correlation between ACT participation rate and the state's average composite scores, with a correlation value of -0.867 calculated. States that report higher participation rates in ACT tend to report lower composite scores in the exam.

# %%
sns_scatter(
    df_final,
    "sat19_part_rate", 
    "sat19_total_score",
    "SAT 2019 participation rate",
    "SAT 2019 total score",
    "How are SAT scores correlated with its participation rate?"
    )

plt.savefig('scatter_sat19_scorepart', bbox_inches = 'tight')
# Out:
# Correlation between sat19_part_rate and sat19_total_score is: -0.8617856279968544.

# %% [markdown]
# ##### Relationship between each state's SAT participation rate and its average total score
# Similarly, there is a negative correlation between SAT participation rate and the state's average composite scores, with a correlation value of -0.862 calculated. States that report higher participation rates in SAT also tend to report lower total score averages in the exam.

# %%
# define function to draw up boxplots

def draw_boxplot(mydf, title, ytitle, xticks, ylim):
    
    plt.figure(figsize=(12,8))
    #mean is indicated on the graphs by the white triangles
    ax = sns.boxplot(data=mydf, showmeans=True, meanprops={"markerfacecolor":"white", "markeredgecolor":"white"}) 
    ax.set_title(title, size=15)
    ax.set_ylabel(ytitle,size=15)
    ax.set_ylim(ylim)
    
    ax.set_xticklabels(xticks,size=15)

# %%
# comparing ACT participation rates from 2017 to 2019

draw_boxplot(
    df_final[['act17_part_rate', 'act18_part_rate', 'act19_part_rate']], 
    'ACT participation rates', 
    'Participation Rate',  
    ["ACT 2017", "ACT 2018", "ACT 2019"],
    [0.00,1.50]
    )

plt.savefig('act17_18_19_partbox.png', bbox_inches = 'tight')

# %% [markdown]
# ##### How has ACT participation rate changed over the years?
# In general, highest participation rate continued to be 100% from 2017 to 2019. This would represent the states with school systems that make ACT mandatory and/or administer the ACT for free on a school day. In states where student can sit for the ACT for free, participation rate continued to be 100% from 2017 to 2019.
#
#
# However, median ACT participation rate nationally dropped from 2017 through 2019, showing that in several states where participation was not 100%, less and less students applied to sit for the ACT. The mean ACT participation rate also dropped from 2017 through 2019, which meant that in general, the ACT is falling out of favour among the test-taker population.

# %%
# comparing ACT composite scores from 2017 to 2019

draw_boxplot(
    df_final[['act17_com_score', 'act18_com_score', 'act19_com_score']], 
    'ACT composite score', 
    'Composite Score',  
    ["ACT 2017", "ACT 2018", "ACT 2019"],
    [15,30]
    )

plt.savefig('act17_18_19_scorebox.png', bbox_inches = 'tight')

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# In general, participation rates for both the ACT and the SAT has a strong positive correlation with whether students can sit for the respective exams for free. While it is likely that the removal of financial costs and the ability to sit for the exam conveniently on a school day encouraged more students to participate, it should be noted that some states had made the exams mandatory for high school graduands. For example, Montana, Nebraska and Nevada which set the ACT as the sole high school exit exam reported a 100% ACT participation rate. Similarly, Connecticut, Maine, New Hampshire and West Virginia which set the SAT as the sole high school exit exam reported a 100% SAT participation rate.
#
# While the lowering of barriers had motivated greater exam participation, it is seen that overall state averages simultaneously suffer for both the ACT and SAT respectively. However, this should not be the impetus to make the ACT fees to be fully student-borne nor to make the ACT optional for high school graduands across the country. It is a curious trend that bears further study. For example, studies should be furthered to query and analyse students and teaching faculties' perception of the ACT's relevance in college admissions, as well as the standard of preparation for the ACT in states which have made it a prerequisite for high school graduation.
#
# To maintain high participation rates in states that make it mandatory, I suggest keeping the contracts with these states and school systems  that administer ACT for free. This significantly lowers barriers to entry for students in underserved populations that belong to more than one of these categories: from minority ethnicity, from low-income household, from family where parents are not college graduates.
#
# Secondly, to add focus on marketing the ACT exam in states and school systems where SAT is prevalent choice. By angling it as a welcome additional metric to profile a high-achieving student, ACT, inc can increase its market share of the test-taking population and thus participation rates.
#
# Thirdly, to update test conditions to make it more equitable for all students. Aagard postulates that there is a significant relationship between testing condition and student test scores for students of various capabilities <a href="https://www.thefreelibrary.com/The+relationship+between+testing+condition+and+student+test+scores.-a0126582635" target="_blank">(source)</a> This can help to boost performance of low-achieving students who form bulk of underserved student population and improve their college admission chances.
